# %% [markdown]
# ### BASELINE MODEL

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Reat the data into pandas DataFrames

df = pd.read_csv('train_features.csv')
df_test = pd.read_csv('train_labels.csv')

df.head()
# Out:
#       id  amount_tsh date_recorded        funder  gps_height     installer  \
# 0  69572      6000.0    2011-03-14         Roman        1390         Roman
# 1   8776         0.0    2013-03-06       Grumeti        1399       GRUMETI
# 2  34310        25.0    2013-02-25  Lottery Club         686  World vision
# 3  67743         0.0    2013-01-28        Unicef         263        UNICEF
# 4  19728         0.0    2011-07-13   Action In A           0       Artisan
#
#    longitude   latitude              wpt_name  num_private  ... payment_type  \
# 0  34.938093  -9.856322                  none            0  ...     annually
# 1  34.698766  -2.147466              Zahanati            0  ...    never pay
# 2  37.460664  -3.821329           Kwa Mahundi            0  ...   per bucket
# 3  38.486161 -11.155298  Zahanati Ya Nanyumbu            0  ...    never pay
# 4  31.130847  -1.825359               Shuleni            0  ...    never pay
#
# ...

# %%
df.shape
# Out:
# (59400, 40)

# %%
df_test.head()
# Out:
#       id    status_group
# 0  69572      functional
# 1   8776      functional
# 2  34310      functional
# 3  67743  non functional
# 4  19728      functional

# %%
df_test.shape
# Out:
# (59400, 2)

# %%
# Combine the DataFrames 
# Remember, target variable is 'status_group'

df_combined = df.merge(df_test, on='id', how='left')
df_combined.head()
# Out:
#       id  amount_tsh date_recorded        funder  gps_height     installer  \
# 0  69572      6000.0    2011-03-14         Roman        1390         Roman
# 1   8776         0.0    2013-03-06       Grumeti        1399       GRUMETI
# 2  34310        25.0    2013-02-25  Lottery Club         686  World vision
# 3  67743         0.0    2013-01-28        Unicef         263        UNICEF
# 4  19728         0.0    2011-07-13   Action In A           0       Artisan
#
#    longitude   latitude              wpt_name  num_private  ... water_quality  \
# 0  34.938093  -9.856322                  none            0  ...          soft
# 1  34.698766  -2.147466              Zahanati            0  ...          soft
# 2  37.460664  -3.821329           Kwa Mahundi            0  ...          soft
# 3  38.486161 -11.155298  Zahanati Ya Nanyumbu            0  ...          soft
# 4  31.130847  -1.825359               Shuleni            0  ...          soft
#
# ...

# %%
df_combined.dtypes
# Out:
# id                         int64
# amount_tsh               float64
# date_recorded             object
# funder                    object
# gps_height                 int64
# installer                 object
# longitude                float64
# latitude                 float64
# wpt_name                  object
# num_private                int64
# basin                     object
# subvillage                object
# region                    object
# region_code                int64
# district_code              int64
# lga                       object
# ward                      object
# population                 int64
# public_meeting            object
# recorded_by               object
# scheme_management         object
# scheme_name               object
# permit                    object
# construction_year          int64
# extraction_type           object
# extraction_type_group     object
# extraction_type_class     object
# management                object
# ...

# %%
df_combined.isna().sum()
# Out:
# id                           0
# amount_tsh                   0
# date_recorded                0
# funder                    3635
# gps_height                   0
# installer                 3655
# longitude                    0
# latitude                     0
# wpt_name                     0
# num_private                  0
# basin                        0
# subvillage                 371
# region                       0
# region_code                  0
# district_code                0
# lga                          0
# ward                         0
# population                   0
# public_meeting            3334
# recorded_by                  0
# scheme_management         3877
# scheme_name              28166
# permit                    3056
# construction_year            0
# extraction_type              0
# extraction_type_group        0
# extraction_type_class        0
# management                   0
# management_group             0
# payment                      0
# ...

# %%
# Just the numerical data

df_combined_num = df_combined.select_dtypes(include=['number']).copy()
df_combined_num.head()
# Out:
#       id  amount_tsh  gps_height  longitude   latitude  num_private  \
# 0  69572      6000.0        1390  34.938093  -9.856322            0
# 1   8776         0.0        1399  34.698766  -2.147466            0
# 2  34310        25.0         686  37.460664  -3.821329            0
# 3  67743         0.0         263  38.486161 -11.155298            0
# 4  19728         0.0           0  31.130847  -1.825359            0
#
#    region_code  district_code  population  construction_year
# 0           11              5         109               1999
# 1           20              2         280               2010
# 2           21              4         250               2009
# 3           90             63          58               1986
# 4           18              1           0                  0

# %%
# add the target variable to the numeric

df_combined_num['target'] = df_combined['status_group']
df_combined_num.head()
# Out:
#       id  amount_tsh  gps_height  longitude   latitude  num_private  \
# 0  69572      6000.0        1390  34.938093  -9.856322            0
# 1   8776         0.0        1399  34.698766  -2.147466            0
# 2  34310        25.0         686  37.460664  -3.821329            0
# 3  67743         0.0         263  38.486161 -11.155298            0
# 4  19728         0.0           0  31.130847  -1.825359            0
#
#    region_code  district_code  population  construction_year          target
# 0           11              5         109               1999      functional
# 1           20              2         280               2010      functional
# 2           21              4         250               2009      functional
# 3           90             63          58               1986  non functional
# 4           18              1           0                  0      functional

# %%
# no null values for the Numeric DataFrame

df_combined_num.isna().sum()
# Out:
# id                   0
# amount_tsh           0
# gps_height           0
# longitude            0
# latitude             0
# num_private          0
# region_code          0
# district_code        0
# population           0
# construction_year    0
# target               0
# dtype: int64

# %%
df_combined_num.shape
# Out:
# (59400, 11)

# %%
# target variable seems to be shuffled

df_combined_num['target'].head(100)
# Out:
# 0                  functional
# 1                  functional
# 2                  functional
# 3              non functional
# 4                  functional
# 5                  functional
# 6              non functional
# 7              non functional
# 8              non functional
# 9                  functional
# 10                 functional
# 11                 functional
# 12                 functional
# 13                 functional
# 14                 functional
# 15                 functional
# 16             non functional
# 17             non functional
# 18    functional needs repair
# 19                 functional
# 20                 functional
# 21                 functional
# 22    functional needs repair
# 23                 functional
# 24                 functional
# 25    functional needs repair
# 26                 functional
# 27                 functional
# 28             non functional
# 29                 functional
#                ...
# ...

# %%
df_combined_num['target'].value_counts(normalize=True)
# Out:
# functional                 0.543081
# non functional             0.384242
# functional needs repair    0.072677
# Name: target, dtype: float64

# %% [markdown]
# #### The majority class is funtioncal (54%), so 54% is the baseline accuracy

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

X = df_combined_num.loc[:, 'id':'construction_year']
y = df_combined_num['target']

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

lr = LogisticRegression().fit(X_train, y_train)

y_preds = lr.predict(X_test)

print("Training set score: {:.2f}".format(lr.score(X_train,y_train)))
print("Test set score: {:.2f}".format(lr.score(X_test, y_test)))
# Out:
# /Users/sammylee/miniconda3/envs/datascience/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /Users/sammylee/miniconda3/envs/datascience/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# Training set score: 0.55
# Test set score: 0.55

# %%
y_preds[:5]
# Out:
# array(['functional', 'functional', 'functional', 'functional',
#        'functional'], dtype=object)

# %%
df_test = pd.read_csv('test_features.csv')
df_test.head()
# Out:
#       id  amount_tsh date_recorded                  funder  gps_height  \
# 0  50785         0.0    2013-02-04                    Dmdd        1996
# 1  51630         0.0    2013-02-04  Government Of Tanzania        1569
# 2  17168         0.0    2013-02-01                     NaN        1567
# 3  45559         0.0    2013-01-22              Finn Water         267
# 4  49871       500.0    2013-03-27                  Bruder        1260
#
#     installer  longitude   latitude                 wpt_name  num_private  \
# 0        DMDD  35.290799  -4.059696  Dinamu Secondary School            0
# 1         DWE  36.656709  -3.309214                  Kimnyak            0
# 2         NaN  34.767863  -5.004344           Puma Secondary            0
# 3  FINN WATER  38.058046  -9.418672           Kwa Mzee Pange            0
# 4      BRUDER  35.006123 -10.950412          Kwa Mzee Turuka            0
#
#    ... payment_type water_quality quality_group      quantity  quantity_group  \
# ...

# %%
df_test.isna().sum()
# Out:
# id                          0
# amount_tsh                  0
# date_recorded               0
# funder                    783
# gps_height                  0
# installer                 788
# longitude                   0
# latitude                    0
# wpt_name                    0
# num_private                 0
# basin                       0
# subvillage                 94
# region                      0
# region_code                 0
# district_code               0
# lga                         0
# ward                        0
# population                  0
# public_meeting            785
# recorded_by                 0
# scheme_management         939
# scheme_name              6839
# permit                    663
# construction_year           0
# extraction_type             0
# extraction_type_group       0
# extraction_type_class       0
# management                  0
# management_group            0
# payment                     0
# payment_type                0
# ...

# %%
df_test_num = df_test.select_dtypes(include=['number']).copy()
df_test_num.head()
# Out:
#       id  amount_tsh  gps_height  longitude   latitude  num_private  \
# 0  50785         0.0        1996  35.290799  -4.059696            0
# 1  51630         0.0        1569  36.656709  -3.309214            0
# 2  17168         0.0        1567  34.767863  -5.004344            0
# 3  45559         0.0         267  38.058046  -9.418672            0
# 4  49871       500.0        1260  35.006123 -10.950412            0
#
#    region_code  district_code  population  construction_year
# 0           21              3         321               2012
# 1            2              2         300               2000
# 2           13              2         500               2010
# 3           80             43         250               1987
# 4           10              3          60               2000

# %%
df_test_num.isna().sum()
# Out:
# id                   0
# amount_tsh           0
# gps_height           0
# longitude            0
# latitude             0
# num_private          0
# region_code          0
# district_code        0
# population           0
# construction_year    0
# dtype: int64

# %%
X_test = df_test_num

# %%
test_features_preds = lr.predict(X_test)

test_features_preds
# Out:
# array(['functional', 'functional', 'functional', ..., 'functional',
#        'functional', 'functional'], dtype=object)

# %%
kaggle_baseline_submission = pd.DataFrame({'id': df_test_num.id, 'status_group': test_features_preds})

kaggle_baseline_submission.head()
# Out:
#       id    status_group
# 0  50785      functional
# 1  51630      functional
# 2  17168      functional
# 3  45559  non functional
# 4  49871      functional

# %%
kaggle_baseline_submission.shape
# Out:
# (14358, 2)

# %%
kaggle_baseline_submission.to_csv('kaggle_baseline_submission.csv', index=False)
