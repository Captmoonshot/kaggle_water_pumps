# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df_categorical = pd.read_csv('df_training_combined_categorical.csv', parse_dates=['date_recorded'], na_values=['NaN'])
df_categorical.head()
# Out:
#   date_recorded        funder     installer              wpt_name                    basin  subvillage   region        lga        ward public_meeting              recorded_by scheme_management                  scheme_name permit extraction_type extraction_type_group extraction_type_class management management_group         payment payment_type water_quality quality_group      quantity quantity_group                source           source_type source_class              waterpoint_type waterpoint_type_group     id          target
# 0    2011-03-14         Roman         Roman                  none               Lake Nyasa    Mnyusi B   Iringa     Ludewa    Mundindi           True  GeoData Consultants Ltd               VWC                        Roman  False         gravity               gravity               gravity        vwc       user-group    pay annually     annually          soft          good        enough         enough                spring                spring  groundwater           communal standpipe    communal standpipe  69572      functional
# 1    2013-03-06       Grumeti       GRUMETI              Zahanati            Lake Victoria     Nyamara     Mara  Serengeti       Natta            NaN  GeoData Consultants Ltd             Other                          NaN   True         gravity               gravity               gravity        wug       user-group       never pay    never pay          soft          good  insufficient   insufficient  rainwater harvesting  rainwater harvesting      surface           communal standpipe    communal standpipe   8776      functional
# 2    2013-02-25  Lottery Club  World vision           Kwa Mahundi                  Pangani     Majengo  Manyara  Simanjiro     Ngorika           True  GeoData Consultants Ltd               VWC  Nyumba ya mungu pipe scheme   True         gravity               gravity               gravity        vwc       user-group  pay per bucket   per bucket          soft          good        enough         enough                   dam                   dam      surface  communal standpipe multiple    communal standpipe  34310      functional
# 3    2013-01-28        Unicef        UNICEF  Zahanati Ya Nanyumbu  Ruvuma / Southern Coast  Mahakamani   Mtwara   Nanyumbu    Nanyumbu           True  GeoData Consultants Ltd               VWC                          NaN   True     submersible           submersible           submersible        vwc       user-group       never pay    never pay          soft          good           dry            dry           machine dbh              borehole  groundwater  communal standpipe multiple    communal standpipe  67743  non functional
# 4    2011-07-13   Action In A       Artisan               Shuleni            Lake Victoria  Kyanyamisa   Kagera    Karagwe  Nyakasimbi           True  GeoData Consultants Ltd               NaN                          NaN   True         gravity               gravity               gravity      other            other       never pay    never pay          soft          good      seasonal       seasonal  rainwater harvesting  rainwater harvesting      surface           communal standpipe    communal standpipe  19728      functional

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

# %%
df_categorical.dtypes
# Out:
# date_recorded            datetime64[ns]
# funder                           object
# installer                        object
# wpt_name                         object
# basin                            object
# subvillage                       object
# region                           object
# lga                              object
# ward                             object
# public_meeting                   object
# recorded_by                      object
# scheme_management                object
# scheme_name                      object
# permit                           object
# extraction_type                  object
# extraction_type_group            object
# extraction_type_class            object
# management                       object
# management_group                 object
# payment                          object
# payment_type                     object
# water_quality                    object
# quality_group                    object
# quantity                         object
# quantity_group                   object
# source                           object
# source_type                      object
# source_class                     object
# waterpoint_type                  object
# waterpoint_type_group            object
# id                                int64
# target                           object
# dtype: object

# %%
# pop off the date since it's not really a categorical object variable
date_recorded = df_categorical.pop('date_recorded')
date_recorded.head()
# Out:
# 0   2011-03-14
# 1   2013-03-06
# 2   2013-02-25
# 3   2013-01-28
# 4   2011-07-13
# Name: date_recorded, dtype: datetime64[ns]

# %%
df_categorical.head()
# Out:
#          funder     installer              wpt_name                    basin  subvillage   region        lga        ward public_meeting              recorded_by scheme_management                  scheme_name permit extraction_type extraction_type_group extraction_type_class management management_group         payment payment_type water_quality quality_group      quantity quantity_group                source           source_type source_class              waterpoint_type waterpoint_type_group     id          target
# 0         Roman         Roman                  none               Lake Nyasa    Mnyusi B   Iringa     Ludewa    Mundindi           True  GeoData Consultants Ltd               VWC                        Roman  False         gravity               gravity               gravity        vwc       user-group    pay annually     annually          soft          good        enough         enough                spring                spring  groundwater           communal standpipe    communal standpipe  69572      functional
# 1       Grumeti       GRUMETI              Zahanati            Lake Victoria     Nyamara     Mara  Serengeti       Natta            NaN  GeoData Consultants Ltd             Other                          NaN   True         gravity               gravity               gravity        wug       user-group       never pay    never pay          soft          good  insufficient   insufficient  rainwater harvesting  rainwater harvesting      surface           communal standpipe    communal standpipe   8776      functional
# 2  Lottery Club  World vision           Kwa Mahundi                  Pangani     Majengo  Manyara  Simanjiro     Ngorika           True  GeoData Consultants Ltd               VWC  Nyumba ya mungu pipe scheme   True         gravity               gravity               gravity        vwc       user-group  pay per bucket   per bucket          soft          good        enough         enough                   dam                   dam      surface  communal standpipe multiple    communal standpipe  34310      functional
# 3        Unicef        UNICEF  Zahanati Ya Nanyumbu  Ruvuma / Southern Coast  Mahakamani   Mtwara   Nanyumbu    Nanyumbu           True  GeoData Consultants Ltd               VWC                          NaN   True     submersible           submersible           submersible        vwc       user-group       never pay    never pay          soft          good           dry            dry           machine dbh              borehole  groundwater  communal standpipe multiple    communal standpipe  67743  non functional
# 4   Action In A       Artisan               Shuleni            Lake Victoria  Kyanyamisa   Kagera    Karagwe  Nyakasimbi           True  GeoData Consultants Ltd               NaN                          NaN   True         gravity               gravity               gravity      other            other       never pay    never pay          soft          good      seasonal       seasonal  rainwater harvesting  rainwater harvesting      surface           communal standpipe    communal standpipe  19728      functional

# %%
# separating out 'date_recorded'

date_recorded = pd.concat([df_categorical.id, date_recorded], axis=1)
date_recorded.head()
# Out:
#       id date_recorded
# 0  69572    2011-03-14
# 1   8776    2013-03-06
# 2  34310    2013-02-25
# 3  67743    2013-01-28
# 4  19728    2011-07-13

# %%
df_categorical.head()
# Out:
#          funder     installer              wpt_name                    basin  subvillage   region        lga        ward public_meeting              recorded_by scheme_management                  scheme_name permit extraction_type extraction_type_group extraction_type_class management management_group         payment payment_type water_quality quality_group      quantity quantity_group                source           source_type source_class              waterpoint_type waterpoint_type_group     id          target
# 0         Roman         Roman                  none               Lake Nyasa    Mnyusi B   Iringa     Ludewa    Mundindi           True  GeoData Consultants Ltd               VWC                        Roman  False         gravity               gravity               gravity        vwc       user-group    pay annually     annually          soft          good        enough         enough                spring                spring  groundwater           communal standpipe    communal standpipe  69572      functional
# 1       Grumeti       GRUMETI              Zahanati            Lake Victoria     Nyamara     Mara  Serengeti       Natta            NaN  GeoData Consultants Ltd             Other                          NaN   True         gravity               gravity               gravity        wug       user-group       never pay    never pay          soft          good  insufficient   insufficient  rainwater harvesting  rainwater harvesting      surface           communal standpipe    communal standpipe   8776      functional
# 2  Lottery Club  World vision           Kwa Mahundi                  Pangani     Majengo  Manyara  Simanjiro     Ngorika           True  GeoData Consultants Ltd               VWC  Nyumba ya mungu pipe scheme   True         gravity               gravity               gravity        vwc       user-group  pay per bucket   per bucket          soft          good        enough         enough                   dam                   dam      surface  communal standpipe multiple    communal standpipe  34310      functional
# 3        Unicef        UNICEF  Zahanati Ya Nanyumbu  Ruvuma / Southern Coast  Mahakamani   Mtwara   Nanyumbu    Nanyumbu           True  GeoData Consultants Ltd               VWC                          NaN   True     submersible           submersible           submersible        vwc       user-group       never pay    never pay          soft          good           dry            dry           machine dbh              borehole  groundwater  communal standpipe multiple    communal standpipe  67743  non functional
# 4   Action In A       Artisan               Shuleni            Lake Victoria  Kyanyamisa   Kagera    Karagwe  Nyakasimbi           True  GeoData Consultants Ltd               NaN                          NaN   True         gravity               gravity               gravity      other            other       never pay    never pay          soft          good      seasonal       seasonal  rainwater harvesting  rainwater harvesting      surface           communal standpipe    communal standpipe  19728      functional

# %%
df_categorical.shape
# Out:
# (59400, 31)

# %%
df_categorical.isna().sum()
# Out:
# funder                    3635
# installer                 3655
# wpt_name                     0
# basin                        0
# subvillage                 371
# region                       0
# lga                          0
# ward                         0
# public_meeting            3334
# recorded_by                  0
# scheme_management         3877
# scheme_name              28166
# permit                    3056
# extraction_type              0
# extraction_type_group        0
# extraction_type_class        0
# management                   0
# management_group             0
# payment                      0
# payment_type                 0
# water_quality                0
# quality_group                0
# quantity                     0
# quantity_group               0
# source                       0
# source_type                  0
# source_class                 0
# waterpoint_type              0
# waterpoint_type_group        0
# id                           0
# target                       0
# dtype: int64

# %%
df_categorical['funder'].mode()[0]
# Out:
# 'Government Of Tanzania'

# %%
df_categorical['funder'] = df_categorical['funder'].fillna(df_categorical['funder'].mode()[0])

# %%
df_categorical['funder'].isna().sum()
# Out:
# 0

# %%
df_categorical['funder'].value_counts(normalize=True)
# Out:
# Government Of Tanzania            0.214125
# Danida                            0.052424
# Hesawa                            0.037071
# Rwssp                             0.023131
# World Bank                        0.022710
# Kkkt                              0.021667
# World Vision                      0.020976
# Unicef                            0.017795
# Tasaf                             0.014764
# District Council                  0.014192
# Dhv                               0.013956
# Private Individual                0.013906
# Dwsp                              0.013653
# 0                                 0.013081
# Norad                             0.012879
# Germany Republi                   0.010269
# Tcrs                              0.010135
# Ministry Of Water                 0.009933
# Water                             0.009815
# Dwe                               0.008148
# Netherlands                       0.007912
# Hifab                             0.007576
# Adb                               0.007542
# Lga                               0.007441
# Amref                             0.007155
# Fini Water                        0.006616
# Oxfam                             0.006044
# Wateraid                          0.005606
# Rc Church                         0.005404
# Isf                               0.005320
# Rudep                             0.005253
# Mission                           0.005067
# Private                           0.004966
# Jaica                             0.004714
# Roman                             0.004630
# Rural Water Supply And Sanitat    0.004545
# Adra                              0.004428
# Ces(gmbh)                         0.004377
# Jica                              0.004360
# Shipo                             0.004057
# Wsdp                              0.003939
# Rc                                0.003872
# Finw                              0.003687
# Dh                                0.003586
# Ded                               0.003333
# Plan Int                          0.003283
# Kiliwater                         0.003182
# Dmdd                              0.003131
# Go                                0.003047
# Lawatefuka Water Supply           0.003030
# Oxfarm                            0.002963
# Magadini-makiwaru Water           0.002946
# Fw                                0.002912
# W.B                               0.002862
# Kkkt_makwale                      0.002795
# Ces (gmbh)                        0.002778
# Wvt                               0.002660
# Oikos E.Afrika                    0.002609
# Nethalan                          0.002559
# Mkinga Distric Coun               0.002525
# Lvia                              0.002475
# Concern World Wide                0.002441
# Unhcr                             0.002306
# No                                0.002256
# Swedish                           0.002205
# African                           0.002155
# Community                         0.002121
# Anglican Church                   0.002121
# He                                0.002104
# Is                                0.002104
# Ki                                0.002088
# Ir                                0.002071
# Tardo                             0.002071
# Wananchi                          0.002054
# Snv                               0.002054
# Wua                               0.002037
# Roman Catholic                    0.002037
# Unice                             0.002003
# Bsf                               0.001970
# Tassaf                            0.001953
# Co                                0.001869
# Dfid                              0.001852
# Lamp                              0.001852
# Concern                           0.001818
# Muwsa                             0.001801
# Villagers                         0.001785
# Ru                                0.001768
# Village Council                   0.001768
# Halmashauri Ya Wilaya Sikonge     0.001717
# Hsw                               0.001700
# Germany                           0.001700
# Twe                               0.001633
# Idc                               0.001549
# Tanza                             0.001481
# Missi                             0.001465
# Undp                              0.001448
# H                                 0.001448
# Mdrdp                             0.001448
# Aict                              0.001431
# Gtz                               0.001414
# Japan                             0.001380
# Cmsr                              0.001364
# Rc Ch                             0.001347
# Ndrdp                             0.001313
# Vwc                               0.001313
# Lwi                               0.001212
# Fin Water                         0.001212
# Kuwait                            0.001212
# Kkkt Church                       0.001178
# Cdtf                              0.001178
# Caritas                           0.001178
# Kaemp                             0.001162
# Padep                             0.001162
# Conce                             0.001145
# Water Aid /sema                   0.001145
# Kibaha Town Council               0.001145
# Marafip                           0.001145
# Cefa                              0.001128
# Ncaa                              0.001061
# Commu                             0.001044
# Mkinga  Distric Cou               0.001044
# National Rural                    0.001044
# Losaa-kia Water Supply            0.001044
# Md                                0.001027
# Irish Ai                          0.000993
# Sabemo                            0.000993
# Plan International                0.000960
# Twesa                             0.000943
# Gen                               0.000909
# St                                0.000909
# Idara Ya Maji                     0.000909
# Kirde                             0.000909
# Tlc                               0.000909
# Grumeti                           0.000892
# Finida German Tanzania Govt       0.000892
# Solidarm                          0.000892
# Kilindi District Co               0.000892
# Cocen                             0.000875
# Wfp                               0.000875
# Tanapa                            0.000859
# Ta                                0.000859
# China Government                  0.000859
# Dwe/norad                         0.000842
# Sema                              0.000842
# Tabora Municipal Council          0.000825
# European Union                    0.000808
# Solidame                          0.000808
# Dwssp                             0.000791
# Ridep                             0.000791
# Acra                              0.000774
# Devon Aid Korogwe                 0.000774
# Miziriol                          0.000774
# Dads                              0.000774
# Shawasa                           0.000758
# Red Cross                         0.000758
# Redep                             0.000741
# Abasia                            0.000724
# Tz Japan                          0.000724
# Giz                               0.000707
# Ms                                0.000707
# Cafod                             0.000690
# Donor                             0.000690
# Tdft                              0.000690
# Serikali                          0.000690
# Soda                              0.000673
# Tredep                            0.000673
# Un                                0.000673
# Ka                                0.000657
# Jbg                               0.000640
# Songea District Council           0.000640
# Kuwasa                            0.000640
# Fathe                             0.000623
# Dasip                             0.000623
# Kidp                              0.000606
# Urt                               0.000606
# W                                 0.000606
# Watu Wa Ujerumani                 0.000589
# Islamic Found                     0.000589
# Songea Municipal Counci           0.000589
# Mbiuwasa                          0.000589
# African Development Bank          0.000589
# Si                                0.000572
# Water User As                     0.000572
# Oikos E.Africa/european Union     0.000556
# Aar                               0.000556
# Ics                               0.000556
# Ilo                               0.000556
# Holland                           0.000556
# Finn Water                        0.000556
# Dhv\norp                          0.000539
# Tuwasa                            0.000539
# Peters                            0.000539
# Kiuma                             0.000539
# Biore                             0.000522
# Kanisa Katoliki Lolovoni          0.000522
# The Desk And Chair Foundat        0.000522
# Cspd                              0.000505
# Jika                              0.000505
# Peter Tesha                       0.000505
# Ga                                0.000505
# Happy Watoto Foundation           0.000505
# Kalta                             0.000505
# Cg                                0.000505
# Swiss If                          0.000505
# Po                                0.000505
# Churc                             0.000505
# World Vision/adra                 0.000488
# Il                                0.000488
# Finwater                          0.000488
# Cocern                            0.000488
# Kidep                             0.000488
# Water Aid/sema                    0.000471
# Undp/ilo                          0.000471
# Ereto                             0.000471
# Save The Rain Usa                 0.000471
# Sida                              0.000471
# Village Government                0.000455
# Songas                            0.000455
# Not Known                         0.000455
# Lips                              0.000455
# Halmashauri                       0.000455
# Hw/rc                             0.000455
# Ifad                              0.000455
# I Wash                            0.000455
# Dw                                0.000455
# Partage                           0.000455
# Kanisa La Menonite                0.000455
# Cdcg                              0.000438
# Mileniam Project                  0.000438
# Nethe                             0.000438
# Wwf                               0.000438
# Plan Internatio                   0.000438
# Quwkwin                           0.000438
# Village                           0.000421
# Hewasa                            0.000421
# Tacare                            0.000421
# Total Land Care                   0.000421
# Dadis                             0.000421
# Rc Churc                          0.000421
# Hans                              0.000421
# Kilwater                          0.000421
# Adp                               0.000421
# Kalitasi                          0.000404
# Missionaries                      0.000404
# Rished                            0.000404
# Tanzakesho                        0.000404
# Roman Cathoric-same               0.000404
# Bgm                               0.000404
# Care International                0.000404
# Cefa-njombe                       0.000387
#                                     ...
# Lc                                0.000017
# Kadip                             0.000017
# Rotaty Club                       0.000017
# Caltas Tanzania                   0.000017
# Dmdd/solider                      0.000017
# Bukumbi                           0.000017
# Cvs Miss                          0.000017
# Kagera                            0.000017
# Swalehe Rajab                     0.000017
# Raramataki                        0.000017
# Juma                              0.000017
# Dhv\swis                          0.000017
# Bathlomew Vicent                  0.000017
# Dae Yeol And Chae Lynn            0.000017
# Jwtz                              0.000017
# Boazi                             0.000017
# Sadaqatun Jar                     0.000017
# Tacri                             0.000017
# Nazalet Church                    0.000017
# Wbk                               0.000017
# Toronto-estate                    0.000017
# Ramadhani M. Mvugalo              0.000017
# Masista                           0.000017
# Shirika La Kinamama Na Watot      0.000017
# Mnyama                            0.000017
# Engineers Without Border          0.000017
# Trc                               0.000017
# Hasnein Murij                     0.000017
# Pori La Akiba Kigosi              0.000017
# Marafin                           0.000017
# Yasi Naini                        0.000017
# Tasa                              0.000017
# Ministry Of Agricultura           0.000017
# Pwc                               0.000017
# Bfwd                              0.000017
# Ilwilo Community                  0.000017
# Hapa Singida                      0.000017
# Mamvua Kakungu                    0.000017
# Fpct Mulala                       0.000017
# Compasion International           0.000017
# Serian                            0.000017
# Songa Hospi                       0.000017
# Mwamama                           0.000017
# Oak'zion' And Bugango B' Commu    0.000017
# Shekhe                            0.000017
# Mwalimu Muhenza                   0.000017
# Rotery C                          0.000017
# Tlc/nyengesa Masanja              0.000017
# Kauzeni                           0.000017
# Caltaz Kahama                     0.000017
# Hesawza                           0.000017
# Member Of Perliament Ahmed Ali    0.000017
# Tquick Wings                      0.000017
# Jamal                             0.000017
# Muhindi                           0.000017
# Kijij                             0.000017
# Norani                            0.000017
# Tgt                               0.000017
# Unp/aict                          0.000017
# Mtewe                             0.000017
# Pangadeco                         0.000017
# Mzee Lesilali                     0.000017
# Buptist                           0.000017
# Elca                              0.000017
# Gra Na Halmashauri                0.000017
# Mwakabalula                       0.000017
# Subvillage                        0.000017
# Mnyamisi Jumaa                    0.000017
# Teonas Wambura                    0.000017
# Petro Patrice                     0.000017
# Ccpk                              0.000017
# Silvester Shilingi                0.000017
# Veo                               0.000017
# Wcst                              0.000017
# Amrefe                            0.000017
# Water Se                          0.000017
# Ilo/undp                          0.000017
# Hassan Gulam                      0.000017
# Dom                               0.000017
# Tanzania /egypt                   0.000017
# Aic Kij                           0.000017
# Nyahale                           0.000017
# Stp-sustainable Tan               0.000017
# Pius Msekwa                       0.000017
# Morad                             0.000017
# Mbozi Hospital                    0.000017
# Richard M.Kyore                   0.000017
# Tree Ways German                  0.000017
# Ms-danish                         0.000017
# Inkinda                           0.000017
# Villlage Contributi               0.000017
# Maseka Community                  0.000017
# Taes                              0.000017
# Crs                               0.000017
# Sharifa Athuman                   0.000017
# Qwekwin                           0.000017
# Mbwana Omari                      0.000017
# Dar Es Salaam Round Table         0.000017
# Mh.Chiza                          0.000017
# Unicrf                            0.000017
# Ku                                0.000017
# Morrovian                         0.000017
# Tlc/emmanuel Kasoga               0.000017
# Jeshi Lawokovu                    0.000017
# Sent Tho                          0.000017
# Kanisa La Neema                   0.000017
# Kwa Makala                        0.000017
# Private Individul                 0.000017
# Grail Mission Kiseki Bar          0.000017
# Padi                              0.000017
# Redekop Digloria                  0.000017
# Makapuchini                       0.000017
# Mrtc                              0.000017
# Koico                             0.000017
# Apm                               0.000017
# Canada Aid                        0.000017
# Cdft                              0.000017
# Tanzaling                         0.000017
# Tz As                             0.000017
# Makonder                          0.000017
# Upendo Primary School             0.000017
# Mzee Mkungata                     0.000017
# Village Res                       0.000017
# Upper Ruvu                        0.000017
# Padri                             0.000017
# Rashid                            0.000017
# Tanga Cement                      0.000017
# Yasini Selemani                   0.000017
# Tansi                             0.000017
# Owner Pingo C                     0.000017
# Muwasa                            0.000017
# Unicef/african Muslim Agency      0.000017
# Ded/rwssp                         0.000017
# Kalitesi                          0.000017
# Afric                             0.000017
# Kitiangare Village Community      0.000017
# Irevea Sister Water               0.000017
# Silinda Yetu                      0.000017
# Maashumu Mohamed                  0.000017
# Mambe                             0.000017
# Meru Concrete                     0.000017
# Kwa Mzee Waziri                   0.000017
# Sido                              0.000017
# Act                               0.000017
# Sda Church                        0.000017
# Msiki                             0.000017
# Government /sda                   0.000017
# Haidomu Lutheran Church           0.000017
# Jeshi La Wokovu [cida]            0.000017
# Community Bank                    0.000017
# O                                 0.000017
# Villages                          0.000017
# Shelisheli Commission             0.000017
# Care/dwe                          0.000017
# Friends Of Ulambo And Mwanhala    0.000017
# Wsdo                              0.000017
# Plan Tanzania                     0.000017
# Unhcr/danida                      0.000017
# Kajima                            0.000017
# Makundya                          0.000017
# Cpps Mission                      0.000017
# Hery                              0.000017
# Jumanne                           0.000017
# Mzee Smith                        0.000017
# Kamama                            0.000017
# Simone                            0.000017
# Mikumi G                          0.000017
# Wards                             0.000017
# Sisal Estste Hale                 0.000017
# Kizenga                           0.000017
# Nerthlands                        0.000017
# Kyela-morogoro                    0.000017
# Wamisionari Wa Kikatoriki         0.000017
# Dokta Mwandulam                   0.000017
# Tanz/egypt Technical  Co-op       0.000017
# Otelo Bussiness Company           0.000017
# Bong-kug Ohh/choonlza Lee         0.000017
# Ramsar                            0.000017
# Vw                                0.000017
# Afroz Ismail                      0.000017
# Prince Medium School              0.000017
# Lgcd                              0.000017
# Eco Lodge                         0.000017
# Kigwa                             0.000017
# Tasaf/tlc                         0.000017
# Haruna Mpog                       0.000017
# Kagunguli Secondary               0.000017
# Magige                            0.000017
# Sipdo                             0.000017
# Mzungu                            0.000017
# John Skwese                       0.000017
# Rajab Seleman                     0.000017
# Afdp                              0.000017
# Mh.J S Sumari                     0.000017
# Roman Cathoric Church             0.000017
# Ambwene Mwaikek                   0.000017
# Wahidi                            0.000017
# World Bank/government             0.000017
# Kanis                             0.000017
# Aqua Blues Angels                 0.000017
# Japan  Food Aid Counter Part      0.000017
# Resolute Golden Pride Project     0.000017
# Luke Samaras Ltd                  0.000017
# Kayempu Ltd                       0.000017
# Kilimarondo Parish                0.000017
# Panone                            0.000017
# Chacha Issame                     0.000017
# Getdsc00                          0.000017
# Ddca                              0.000017
# Misheni                           0.000017
# Misri Government                  0.000017
# Taipo                             0.000017
# Nyangere                          0.000017
# Tbl                               0.000017
# Abdul                             0.000017
# Rural                             0.000017
# Ccp                               0.000017
# Luchelegu Primary School          0.000017
# Kenyans Company                   0.000017
# Water Department                  0.000017
# Kipo Potry                        0.000017
# Fdc                               0.000017
# Seronera                          0.000017
# Mtambo                            0.000017
# Tanload                           0.000017
# Taboma                            0.000017
# Wwf / Fores                       0.000017
# Halimashauli                      0.000017
# St Gasper                         0.000017
# Nyabweta                          0.000017
# Methodist Church                  0.000017
# Romam Catholic                    0.000017
# Bra                               0.000017
# Ndolezi                           0.000017
# Padri K                           0.000017
# Vc                                0.000017
# Swifti                            0.000017
# Rudep/norad                       0.000017
# Dwsdp                             0.000017
# Cgc                               0.000017
# Tabea                             0.000017
# Da Unoperaio Siciliano            0.000017
# District Medical                  0.000017
# Makanya Sisal Estate              0.000017
# Sun-ja Na                         0.000017
# Kopwe Khalifa                     0.000017
# Mwinjuma Mzee                     0.000017
# Pentecostal                       0.000017
# Hashi                             0.000017
# Quicklw                           0.000017
# Name: funder, Length: 1897, dtype: float64

# %%
funder_cleaned = []

for row in df_categorical['funder']:
    if row == 'Government Of Tanzania':
        funder_cleaned.append('Tanzania')
    else:
        funder_cleaned.append('Other')
        
df_categorical['funder_cleaned'] = funder_cleaned
df_categorical['funder_cleaned'].value_counts(normalize=True)
# Out:
# Other       0.785875
# Tanzania    0.214125
# Name: funder_cleaned, dtype: float64

# %%
df_categorical.drop('funder', inplace=True, axis=1)
df_categorical.head()
# Out:
#       installer              wpt_name                    basin  subvillage   region        lga        ward public_meeting              recorded_by scheme_management                  scheme_name permit extraction_type extraction_type_group extraction_type_class management management_group         payment payment_type water_quality quality_group      quantity quantity_group                source           source_type source_class              waterpoint_type waterpoint_type_group     id          target funder_cleaned
# 0         Roman                  none               Lake Nyasa    Mnyusi B   Iringa     Ludewa    Mundindi           True  GeoData Consultants Ltd               VWC                        Roman  False         gravity               gravity               gravity        vwc       user-group    pay annually     annually          soft          good        enough         enough                spring                spring  groundwater           communal standpipe    communal standpipe  69572      functional          Other
# 1       GRUMETI              Zahanati            Lake Victoria     Nyamara     Mara  Serengeti       Natta            NaN  GeoData Consultants Ltd             Other                          NaN   True         gravity               gravity               gravity        wug       user-group       never pay    never pay          soft          good  insufficient   insufficient  rainwater harvesting  rainwater harvesting      surface           communal standpipe    communal standpipe   8776      functional          Other
# 2  World vision           Kwa Mahundi                  Pangani     Majengo  Manyara  Simanjiro     Ngorika           True  GeoData Consultants Ltd               VWC  Nyumba ya mungu pipe scheme   True         gravity               gravity               gravity        vwc       user-group  pay per bucket   per bucket          soft          good        enough         enough                   dam                   dam      surface  communal standpipe multiple    communal standpipe  34310      functional          Other
# 3        UNICEF  Zahanati Ya Nanyumbu  Ruvuma / Southern Coast  Mahakamani   Mtwara   Nanyumbu    Nanyumbu           True  GeoData Consultants Ltd               VWC                          NaN   True     submersible           submersible           submersible        vwc       user-group       never pay    never pay          soft          good           dry            dry           machine dbh              borehole  groundwater  communal standpipe multiple    communal standpipe  67743  non functional          Other
# 4       Artisan               Shuleni            Lake Victoria  Kyanyamisa   Kagera    Karagwe  Nyakasimbi           True  GeoData Consultants Ltd               NaN                          NaN   True         gravity               gravity               gravity      other            other       never pay    never pay          soft          good      seasonal       seasonal  rainwater harvesting  rainwater harvesting      surface           communal standpipe    communal standpipe  19728      functional          Other

# %%
df_categorical.isna().sum()
# Out:
# installer                 3655
# wpt_name                     0
# basin                        0
# subvillage                 371
# region                       0
# lga                          0
# ward                         0
# public_meeting            3334
# recorded_by                  0
# scheme_management         3877
# scheme_name              28166
# permit                    3056
# extraction_type              0
# extraction_type_group        0
# extraction_type_class        0
# management                   0
# management_group             0
# payment                      0
# payment_type                 0
# water_quality                0
# quality_group                0
# quantity                     0
# quantity_group               0
# source                       0
# source_type                  0
# source_class                 0
# waterpoint_type              0
# waterpoint_type_group        0
# id                           0
# target                       0
# funder_cleaned               0
# dtype: int64

# %%
df_categorical['installer'].value_counts(normalize=True)
# Out:
# DWE                              0.312171
# Government                       0.032738
# RWE                              0.021634
# Commu                            0.019015
# DANIDA                           0.018836
# KKKT                             0.016109
# Hesawa                           0.015069
# 0                                0.013938
# TCRS                             0.012683
# Central government               0.011158
# CES                              0.010943
# Community                        0.009920
# DANID                            0.009902
# District Council                 0.009884
# HESAWA                           0.009669
# LGA                              0.007319
# World vision                     0.007319
# WEDECO                           0.007122
# TASAF                            0.007104
# District council                 0.007032
# Gover                            0.006871
# AMREF                            0.005902
# TWESA                            0.005669
# WU                               0.005400
# Dmdd                             0.005148
# ACRA                             0.004987
# World Vision                     0.004843
# SEMA                             0.004467
# DW                               0.004413
# OXFAM                            0.004198
# Da                               0.004018
# Gove                             0.003982
# UNICEF                           0.003982
# Idara ya maji                    0.003982
# Sengerema Water Department       0.003839
# Kiliwater                        0.003767
# NORAD                            0.003731
# FinW                             0.003731
# DH                               0.003624
# Villagers                        0.003570
# DWSP                             0.003444
# Distri                           0.003247
# Lawatefuka water sup             0.003229
# Magadini-Makiwaru wa             0.003139
# RC                               0.003121
# FW                               0.003103
# KKKT _ Konde and DWE             0.002978
# Centr                            0.002906
# WVT                              0.002834
# MWE                              0.002816
# Handeni Trunk Main(              0.002798
# Is                               0.002763
# Norad                            0.002727
# RWSSP                            0.002673
# Fini Water                       0.002673
# SHIPO                            0.002637
# Private                          0.002565
# Kuwait                           0.002547
# JAICA                            0.002529
# Central govt                     0.002476
# ISF                              0.002422
# Artisan                          0.002422
# Fini water                       0.002386
# GOVER                            0.002296
# DDCA                             0.002260
# RC CHURCH                        0.002242
# HE                               0.002242
# Tardo                            0.002206
# Mission                          0.002171
# World                            0.002171
# Ir                               0.002135
# wananchi                         0.002135
# Consulting Engineer              0.002081
# Amref                            0.002045
# JICA                             0.002027
# TWE                              0.001991
# Central Government               0.001973
# MUWSA                            0.001919
# DED                              0.001884
# WATER AID                        0.001848
# FINI WATER                       0.001848
# Halmashauri ya wilaya sikonge    0.001830
# HSW                              0.001794
# Wizara ya maji                   0.001794
# Jaica                            0.001758
# Unisef                           0.001758
# Go                               0.001740
# Ki                               0.001740
# OXFARM                           0.001722
# World Bank                       0.001704
# Roman                            0.001686
# Angli                            0.001650
# VWC                              0.001632
# DMDD                             0.001597
# District water department        0.001597
# Missi                            0.001561
# H                                0.001543
# Shipo                            0.001543
# MDRDP                            0.001507
# DA                               0.001507
# AICT                             0.001507
# Water board                      0.001453
# Oikos E .Africa                  0.001435
# Adra                             0.001435
# District Water Department        0.001399
# Region water Department          0.001381
# Chamavita                        0.001345
# RC Church                        0.001345
# CEFA                             0.001345
# Danid                            0.001292
# Water                            0.001274
# LWI                              0.001274
# KKKT CHURCH                      0.001238
# Wa                               0.001238
# GOVERNMENT                       0.001184
# MTN                              0.001166
# Villa                            0.001166
# TASSAF                           0.001148
# DAWASCO                          0.001148
# GTZ                              0.001130
# Losaa-Kia water supp             0.001112
# Finwater                         0.001112
# Wachina                          0.001076
# LVIA                             0.001076
# Adra/Community                   0.001076
# FIN WATER                        0.001058
# Village Council                  0.001040
# NCAA                             0.001023
# Adra /Community                  0.000987
# ADRA                             0.000987
# GEN                              0.000987
# TLC                              0.000987
# RDC                              0.000987
# Co                               0.000987
# Communit                         0.000969
# Priva                            0.000969
# DHV                              0.000969
# St                               0.000969
# Pr                               0.000951
# RWE/DWE                          0.000933
# wanan                            0.000933
# Local te                         0.000933
# RC Ch                            0.000933
# CDTF                             0.000897
# Water Aid                        0.000861
# WORLD BANK                       0.000843
# Local  technician                0.000843
# KUWAIT                           0.000843
# District water depar             0.000825
# KA                               0.000825
# Miziriol                         0.000825
# Plan Internationa                0.000825
# MLADE                            0.000825
# Local                            0.000807
# SHAWASA                          0.000807
# SOLIDAME                         0.000807
# Water Aid /sema                  0.000789
# TDFT                             0.000753
# Ga                               0.000753
# VILLAGE COUNCIL                  0.000753
# JANDU PLUMBER CO                 0.000735
# CBHCC                            0.000735
# MWE &                            0.000718
# GRUMETI                          0.000700
# KILI WATER                       0.000682
# KUWASA                           0.000682
# SHY BUILDERS                     0.000664
# JBG                              0.000664
# RED CROSS                        0.000646
# KIDP                             0.000646
# MBIUWASA                         0.000628
# BSF                              0.000628
# Ch                               0.000610
# HAPA SINGIDA                     0.000610
# SI                               0.000592
# MUWASA                           0.000592
# KKT                              0.000592
# FINN WATER                       0.000592
# Tanzania Government              0.000592
# Wananchi                         0.000574
# VTECOS                           0.000574
# KIUMA                            0.000574
# TUWASA                           0.000574
# HOLLAND                          0.000556
# LOCAL CONTRACT                   0.000556
# TANAPA                           0.000556
# WATERAID                         0.000556
# The desk and chair foundat       0.000556
# Msabi                            0.000556
# Happy watoto foundation          0.000538
# Kokeni                           0.000538
# Accra                            0.000538
# KAEMP                            0.000538
# WB                               0.000538
# Kalta                            0.000538
# ABASIA                           0.000520
# Swiss If                         0.000520
# Po                               0.000520
# PADEP                            0.000520
# Do                               0.000520
# CCEC                             0.000520
# FinWater                         0.000520
# Gwasco L                         0.000502
# Rhobi                            0.000502
# Jica                             0.000502
# COCANE                           0.000484
# Local technician                 0.000484
# HW/RC                            0.000484
# ERETO                            0.000484
# UN                               0.000484
# GOVERN                           0.000484
# CJEJOW CONSTRUCTION              0.000484
# WD and ID                        0.000466
# Active MKM                       0.000466
# BESADA                           0.000466
# IFAD                             0.000448
# TAWASA                           0.000448
# Kilwater                         0.000448
# ICS                              0.000448
# Serikali                         0.000448
# Hans                             0.000448
# JUIN CO                          0.000448
# TAN PLANT LTD                    0.000448
# Af                               0.000448
# not known                        0.000431
# CMSR                             0.000431
# Wo                               0.000431
# CONS                             0.000431
# Individuals                      0.000431
# Kalitasi                         0.000431
# Mileniam project                 0.000431
# PET                              0.000431
# RIDEP                            0.000431
# JIKA                             0.000431
# GEOTAN                           0.000431
# MTUWASA                          0.000413
# WWF                              0.000413
# TREDEP                           0.000413
# ILCT                             0.000413
# Ce                               0.000413
# Korogwe water works              0.000413
# NYAKILANGANI CO                  0.000413
# KYASHA ENTERPR                   0.000413
# Halmashauri                      0.000413
# VIFAFI                           0.000413
# Total land care                  0.000413
# Hydrotec                         0.000395
# Sabodo                           0.000395
# MARAFIP                          0.000395
# Cosmo                            0.000395
#                                    ...
# BATIST CHURCH                    0.000018
# Upendo Group                     0.000018
# BAPTIST CHURCH OF TANZANIA       0.000018
# GERMAN                           0.000018
# MKONG CONSTRUCTION               0.000018
# Tanza                            0.000018
# WEEPERS                          0.000018
# KKKT Ndrumangeni                 0.000018
# ALIA                             0.000018
# Grobal resource  alliance        0.000018
# Juma                             0.000018
# MOSES                            0.000018
# Pet corporation Ltd              0.000018
# Raramataki                       0.000018
# RC Mi                            0.000018
# Nyabweta                         0.000018
# CH                               0.000018
# Makonde water Population         0.000018
# Others                           0.000018
# Red cross                        0.000018
# Primo                            0.000018
# CHONJA CHARLES                   0.000018
# Goldmain                         0.000018
# LC                               0.000018
# Ramadhani M. Mvugalo             0.000018
# WW                               0.000018
# Halimashauli                     0.000018
# Wizra ya maji na egypt           0.000018
# Nasan workers                    0.000018
# Mzungu                           0.000018
# CEFA/rc church                   0.000018
# HOWARD HUMFREYS                  0.000018
# Makanya Sisal Estate             0.000018
# Di                               0.000018
# TWENDE PAMOJA                    0.000018
# Humfreys Co                      0.000018
# WATER                            0.000018
# HESAWZ                           0.000018
# KAYEMPU LTD                      0.000018
# St Gasper                        0.000018
# RC Njoro                         0.000018
# TINA/Africare                    0.000018
# Mark                             0.000018
# Masjid Nnre                      0.000018
# MACK DONALD CONTRSCTOR           0.000018
# Mwl. Nyerere sec.school          0.000018
# MWANZA                           0.000018
# TUKWALE ENTERP                   0.000018
# care international               0.000018
# JALCA                            0.000018
# Wamissionari wa kikatoriki       0.000018
# Ox                               0.000018
# Rombo delta                      0.000018
# MTAMBO                           0.000018
# Ministry of water                0.000018
# Peter Mayiro                     0.000018
# Misri Government                 0.000018
# MAISHULE                         0.000018
# Lindi rural water department     0.000018
# MasjId Takuar                    0.000018
# Mr Sau                           0.000018
# MAIVARU                          0.000018
# John kiminda co                  0.000018
# Lion's                           0.000018
# BRA                              0.000018
# WINAM CO                         0.000018
# UN Habitat                       0.000018
# Active KMK                       0.000018
# TCRS/ TWESA                      0.000018
# Christopher                      0.000018
# Birage                           0.000018
# NDRDP                            0.000018
# Madra                            0.000018
# Perusi Bhoke                     0.000018
# Swalehe Rajabu                   0.000018
# Maliasili                        0.000018
# Nyamasagi                        0.000018
# Mzee Yassin Naya                 0.000018
# DWE & LWI                        0.000018
# SCHOO                            0.000018
# DADIS                            0.000018
# REGWA                            0.000018
# RWI                              0.000018
# Mwl. Nyerere sec. school         0.000018
# Jerem                            0.000018
# Kuji foundation                  0.000018
# Seif Ndago                       0.000018
# Staford Higima                   0.000018
# JESHI LA WOKOVU                  0.000018
# Monmali                          0.000018
# Buruba                           0.000018
# Shule ya msingi                  0.000018
# Mzee Salum Bakari Darus          0.000018
# HESAWQ                           0.000018
# HAAM                             0.000018
# WWF/                             0.000018
# Tarangire park                   0.000018
# BUMABU                           0.000018
# MASAI LAND                       0.000018
# Juma Makulilo                    0.000018
# Samweli                          0.000018
# Pentecosta                       0.000018
# LUNGWE                           0.000018
# DWW                              0.000018
# KU                               0.000018
# DAWE                             0.000018
# GD&ID                            0.000018
# Jumanne Siabo                    0.000018
# Yohanis Mgaya                    0.000018
# METHODIST CHURCH                 0.000018
# Sakwidi                          0.000018
# Losakia water supply             0.000018
# Leopad Abeid                     0.000018
# DANIAD                           0.000018
# Magani                           0.000018
# Seff Mtambo                      0.000018
# MANGO TREE                       0.000018
# church                           0.000018
# Simon Lusambi                    0.000018
# Bonite Bottles Ltd               0.000018
# JAPAN                            0.000018
# Nyabarongo Kegoro                0.000018
# DWEB                             0.000018
# Nimrod Mkono[mb]                 0.000018
# Babu Sajini                      0.000018
# PNR Da                           0.000018
# GETDSC00                         0.000018
# Motiba Manyanya                  0.000018
# Stephano                         0.000018
# VWT                              0.000018
# Water hu                         0.000018
# Tajiri Jumbe Lila                0.000018
# Wizara  ya maji                  0.000018
# Water Hu                         0.000018
# Enyuati                          0.000018
# Local technical                  0.000018
# CONCE                            0.000018
# Water Aid/DWE                    0.000018
# TANGA CEMENT                     0.000018
# TANCRO                           0.000018
# Zuber Mihungo                    0.000018
# RC MISSIONARY                    0.000018
# BOAZI                            0.000018
# CHINA HENAN CONSTUCTION          0.000018
# Nyakilanganyi                    0.000018
# KARUMBA BIULDIN                  0.000018
# Dawasco                          0.000018
# THREE WAY GERMAN                 0.000018
# Mr Kwi                           0.000018
# OMARY MONA                       0.000018
# Zingibali Secondary              0.000018
# Kikom                            0.000018
# PWD                              0.000018
# Central basin                    0.000018
# MASWI COMPANY                    0.000018
# Governmen                        0.000018
# Mkulima                          0.000018
# Mamaz                            0.000018
# DADS/village Community           0.000018
# Tareto                           0.000018
# KKKT Kilinga                     0.000018
# William Acles                    0.000018
# TLC/Emmanuel Kasoga              0.000018
# Japan Government                 0.000018
# Moshono ADP                      0.000018
# Hemed Abdalkah                   0.000018
# Islamic community                0.000018
# Water  Aid/Maji tech             0.000018
# REGWA Company                    0.000018
# Got                              0.000018
# Ansnani Murij                    0.000018
# CHRISTAN OUTRICH                 0.000018
# UDEA                             0.000018
# EGYPT REGWA                      0.000018
# HESAW                            0.000018
# SIMBA LODGE                      0.000018
# TCRS a                           0.000018
# Mara inter product               0.000018
# Mombo urban  water               0.000018
# FINI Water                       0.000018
# Grail Mission Kiseki bar         0.000018
# Amadi                            0.000018
# TASAF 1                          0.000018
# TANCAN                           0.000018
# Kuweit                           0.000018
# Njula                            0.000018
# Marijan Ally Dadi                0.000018
# EMANDA                           0.000018
# DWE/TASSAF                       0.000018
# Mambe                            0.000018
# Piscop                           0.000018
# AQUA Wat                         0.000018
# Government of Misri              0.000018
# TCRS/TWESA                       0.000018
# Mgaya                            0.000018
# TECH SUPPORT BEST CO             0.000018
# Wamisionari wa Kikatoriki        0.000018
# Rhobi Wamburs                    0.000018
# TLC/community                    0.000018
# Yasini                           0.000018
# Bahresa                          0.000018
# Gesine                           0.000018
# Deus Ndege                       0.000018
# Municipal Council                0.000018
# WSSP                             0.000018
# Handeni Trunk Main               0.000018
# Wilson                           0.000018
# Government /TCRS                 0.000018
# Mwita Lucas                      0.000018
# SERONERA                         0.000018
# Villi                            0.000018
# Mbusi Mwita                      0.000018
# Kuwaiti                          0.000018
# Sua                              0.000018
# Quick win project /Council       0.000018
# Salum Tambalizeni                0.000018
# Ju                               0.000018
# Noshadi                          0.000018
# QUICKWINS                        0.000018
# TCRS/ TASSAF                     0.000018
# DANIDS                           0.000018
# Netherlands                      0.000018
# DANIDA CO                        0.000018
# Rotary club kitchener            0.000018
# TWESS                            0.000018
# Ilaramataki                      0.000018
# Africa M                         0.000018
# Steven Nyangarika                0.000018
# mwita kichere                    0.000018
# Saidi Halfani                    0.000018
# Mohamad Masanga                  0.000018
# NYAKILANGANI  CO                 0.000018
# Jackson Makore                   0.000018
# Warento                          0.000018
# Water department                 0.000018
# AIXOS                            0.000018
# SDA CHURCH                       0.000018
# JSICA                            0.000018
# Megis                            0.000018
# Rashid Seng'ombe                 0.000018
# DIMON                            0.000018
# Tanzania/ Egypt                  0.000018
# Yakwetu Contractor               0.000018
# ISF / TASAFF                     0.000018
# E ETO                            0.000018
# Rudri                            0.000018
# MBUZI MAWE                       0.000018
# Aartisa                          0.000018
# Morrov                           0.000018
# KKKT MAREU                       0.000018
# Name: installer, Length: 2145, dtype: float64

# %%
installer_cleaned = []

for row in df_categorical['installer']:
    if row == 'DWE':
        installer_cleaned.append('DWE')
    else:
        installer_cleaned.append('Other')
        
df_categorical['installer_cleaned'] = installer_cleaned
df_categorical['installer_cleaned'].value_counts(normalize=True)
# Out:
# Other    0.707037
# DWE      0.292963
# Name: installer_cleaned, dtype: float64

# %%
df_categorical.drop('installer', inplace=True, axis=1)
df_categorical.head()
# Out:
#                wpt_name                    basin  subvillage   region        lga        ward public_meeting              recorded_by scheme_management                  scheme_name permit extraction_type extraction_type_group extraction_type_class management management_group         payment payment_type water_quality quality_group      quantity quantity_group                source           source_type source_class              waterpoint_type waterpoint_type_group     id          target funder_cleaned installer_cleaned
# 0                  none               Lake Nyasa    Mnyusi B   Iringa     Ludewa    Mundindi           True  GeoData Consultants Ltd               VWC                        Roman  False         gravity               gravity               gravity        vwc       user-group    pay annually     annually          soft          good        enough         enough                spring                spring  groundwater           communal standpipe    communal standpipe  69572      functional          Other             Other
# 1              Zahanati            Lake Victoria     Nyamara     Mara  Serengeti       Natta            NaN  GeoData Consultants Ltd             Other                          NaN   True         gravity               gravity               gravity        wug       user-group       never pay    never pay          soft          good  insufficient   insufficient  rainwater harvesting  rainwater harvesting      surface           communal standpipe    communal standpipe   8776      functional          Other             Other
# 2           Kwa Mahundi                  Pangani     Majengo  Manyara  Simanjiro     Ngorika           True  GeoData Consultants Ltd               VWC  Nyumba ya mungu pipe scheme   True         gravity               gravity               gravity        vwc       user-group  pay per bucket   per bucket          soft          good        enough         enough                   dam                   dam      surface  communal standpipe multiple    communal standpipe  34310      functional          Other             Other
# 3  Zahanati Ya Nanyumbu  Ruvuma / Southern Coast  Mahakamani   Mtwara   Nanyumbu    Nanyumbu           True  GeoData Consultants Ltd               VWC                          NaN   True     submersible           submersible           submersible        vwc       user-group       never pay    never pay          soft          good           dry            dry           machine dbh              borehole  groundwater  communal standpipe multiple    communal standpipe  67743  non functional          Other             Other
# 4               Shuleni            Lake Victoria  Kyanyamisa   Kagera    Karagwe  Nyakasimbi           True  GeoData Consultants Ltd               NaN                          NaN   True         gravity               gravity               gravity      other            other       never pay    never pay          soft          good      seasonal       seasonal  rainwater harvesting  rainwater harvesting      surface           communal standpipe    communal standpipe  19728      functional          Other             Other

# %%
df_categorical.isna().sum()
# Out:
# wpt_name                     0
# basin                        0
# subvillage                 371
# region                       0
# lga                          0
# ward                         0
# public_meeting            3334
# recorded_by                  0
# scheme_management         3877
# scheme_name              28166
# permit                    3056
# extraction_type              0
# extraction_type_group        0
# extraction_type_class        0
# management                   0
# management_group             0
# payment                      0
# payment_type                 0
# water_quality                0
# quality_group                0
# quantity                     0
# quantity_group               0
# source                       0
# source_type                  0
# source_class                 0
# waterpoint_type              0
# waterpoint_type_group        0
# id                           0
# target                       0
# funder_cleaned               0
# installer_cleaned            0
# dtype: int64

# %%
df_categorical['subvillage'].value_counts(normalize=True)
# Out:
# Madukani                          0.008606
# Shuleni                           0.008572
# Majengo                           0.008504
# Kati                              0.006319
# Mtakuja                           0.004438
# Sokoni                            0.003930
# M                                 0.003168
# Muungano                          0.002914
# Mbuyuni                           0.002778
# Mlimani                           0.002575
# Songambele                        0.002490
# Msikitini                         0.002270
# Miembeni                          0.002270
# 1                                 0.002236
# Kibaoni                           0.001931
# Kanisani                          0.001880
# I                                 0.001847
# Mapinduzi                         0.001847
# Mjini                             0.001830
# Mjimwema                          0.001830
# Mkwajuni                          0.001762
# Mwenge                            0.001728
# Azimio                            0.001660
# Mabatini                          0.001660
# Mbugani                           0.001609
# Mission                           0.001609
# Bwawani                           0.001542
# Bondeni                           0.001525
# Chang'Ombe                        0.001491
# Zahanati                          0.001457
# Kichangani                        0.001423
# Mtaa Wa Kitunda Kati              0.001423
# Senta                             0.001423
# Misufini                          0.001406
# Center                            0.001389
# Nyerere                           0.001338
# Amani                             0.001304
# K                                 0.001304
# Kawawa                            0.001304
# Kisiwani                          0.001271
# Maendeleo                         0.001169
# Ccm                               0.001101
# Ikulu                             0.001050
# Ilala                             0.001033
# Ushirika                          0.001016
# Shule                             0.001000
# Marurani Kati                     0.001000
# Mtaa Wa Kivule                    0.001000
# Gulioni                           0.001000
# Uzunguni                          0.000983
# Darajani                          0.000983
# Barabarani                        0.000949
# Magharibi                         0.000932
# Sokoine                           0.000915
# Marurani Juu                      0.000915
# Mpakani                           0.000898
# Dodoma                            0.000881
# Msufini                           0.000881
# Kaloleni                          0.000864
# Magomeni                          0.000864
# Elimu                             0.000830
# Ofisini                           0.000813
# Mkuyuni                           0.000813
# Msumbiji                          0.000813
# Misheni                           0.000813
# Bomani                            0.000813
# Mtaa Wa Vikongoro                 0.000796
# Kilimahewa                        0.000779
# Minazini                          0.000762
# Zaire                             0.000762
# Katumba                           0.000745
# Mnadani                           0.000745
# Ujamaa                            0.000728
# Mnazi Mmoja                       0.000695
# Vikuge                            0.000695
# Uswahilini                        0.000695
# Usalama                           0.000695
# Mikoroshini                       0.000695
# Ngelele                           0.000695
# Mtoni                             0.000678
# Mnazimmoja                        0.000678
# Bombani                           0.000678
# Muongozo                          0.000678
# Stendi                            0.000661
# Mwabasabi                         0.000661
# Mashariki                         0.000644
# Tangini                           0.000644
# Maweni                            0.000627
# Kijijini                          0.000610
# Temeke                            0.000610
# Mchangani                         0.000610
# Chemchem                          0.000610
# Njia Panda                        0.000593
# Mtaa Wa Kipunguni B               0.000593
# Mwangaza                          0.000593
# Tankini                           0.000593
# Njiapanda                         0.000593
# Kabale                            0.000576
# Isanga                            0.000576
# Kiwanjani                         0.000576
# Migombani                         0.000576
# Umoja                             0.000576
# Tandika                           0.000559
# Gezaulole                         0.000559
# Lugombo                           0.000559
# Kibaoni B                         0.000559
# Ukombozi                          0.000542
# L                                 0.000542
# Mpuguso                           0.000542
# Makungu                           0.000542
# Kijiweni                          0.000542
# Kakola                            0.000542
# Kisesa                            0.000525
# Kaskazini                         0.000525
# U                                 0.000525
# Matale                            0.000525
# Kigamboni                         0.000525
# Mwandege                          0.000525
# Majengo B                         0.000525
# Majengo A                         0.000525
# Juhudi                            0.000508
# S                                 0.000508
# Mpanda                            0.000508
# Kagera                            0.000508
# Stooni                            0.000508
# Mandela                           0.000491
# Kivukoni                          0.000491
# Lusungo                           0.000491
# Stesheni                          0.000491
# K/Center                          0.000474
# Moivaro                           0.000474
# Uhuru                             0.000474
# Bagamoyo                          0.000474
# Lupaso                            0.000457
# Mwandu                            0.000457
# Kilimanihewa                      0.000457
# Jangwani                          0.000457
# Majimaji                          0.000457
# Mwabayanda                        0.000457
# Bujingwa                          0.000440
# Ulkusare                          0.000440
# Legeza Mwendo                     0.000440
# Magereza                          0.000440
# Mtaa Wa Mzinga                    0.000440
# Mwaya                             0.000440
# Mazengo                           0.000440
# Kabanga                           0.000440
# N                                 0.000440
# Mtukula                           0.000440
# Sekondari                         0.000424
# Kongei                            0.000424
# Mtaa Wa Kichangani                0.000424
# Afya                              0.000424
# Chakwale Mjini                    0.000424
# Juu                               0.000424
# Nmc                               0.000424
# Msolwa Kati                       0.000424
# Igalula                           0.000407
# Makuyuni                          0.000407
# Mlangali                          0.000407
# Karume                            0.000407
# Mwinyi                            0.000407
# Kizani                            0.000407
# Huduma                            0.000407
# Kariakoo                          0.000390
# Mwembeni                          0.000390
# Magunga                           0.000390
# Mvuleni                           0.000390
# Manzese                           0.000390
# Maji Coast                        0.000390
# Kasanga                           0.000390
# Posta                             0.000390
# Makiungu                          0.000390
# Mbuyuni B                         0.000390
# Mshikamano                        0.000390
# Station                           0.000390
# Relini                            0.000373
# Centre                            0.000373
# Tanesco                           0.000373
# Mwamala                           0.000373
# Jitegemee                         0.000373
# Msasani                           0.000373
# Mpirani                           0.000373
# Upendo                            0.000373
# Mahenge                           0.000373
# Kumsenga                          0.000373
# Barabara 2                        0.000356
# Kidalini                          0.000356
# Magwila                           0.000356
# Mkongo                            0.000356
# Mapambano                         0.000356
# Nyashimba                         0.000356
# Central                           0.000356
# Masebe                            0.000356
# Kusini                            0.000356
# Kihanga                           0.000356
# Lusinde                           0.000356
# Mpunguti                          0.000356
# Bunukangoma                       0.000356
# Kiwili                            0.000356
# Namba Moja                        0.000356
# Mgudeni                           0.000356
# Arauyo                            0.000356
# Barabara 6                        0.000356
# Nyange                            0.000356
# Barazani                          0.000356
# Pemba                             0.000339
# Madukani B                        0.000339
# Matumbi                           0.000339
# Njia Nne                          0.000339
# Kigero                            0.000339
# Misri                             0.000339
# Hospitali                         0.000339
# Barabara 9                        0.000339
# Nyabihore                         0.000339
# Ilolo                             0.000339
# Rc                                0.000339
# Magatini                          0.000339
# Msasa                             0.000339
# Lungemba                          0.000339
# Tupendane                         0.000339
# Barabara 4                        0.000339
# Makundusi                         0.000322
# Mpanda Kati                       0.000322
# Chamwino                          0.000322
# Kayenze                           0.000322
# Soko                              0.000322
# Mtakuja A                         0.000322
# Kasala                            0.000322
# Nkokwa                            0.000322
# Magadini                          0.000322
# Engikaleti                        0.000322
# Barabara 3                        0.000322
# Dukani                            0.000322
# Bomu                              0.000322
# Motomoto                          0.000322
# Msitu Wa Tembo B                  0.000322
# Kilambo                           0.000305
# Kumba                             0.000305
# Soweto                            0.000305
# Kazamoyo                          0.000305
# Njoro                             0.000305
# Nyanza                            0.000305
# Kashishi                          0.000305
# Kilimani                          0.000305
# Mkese                             0.000305
# Saweni                            0.000305
# Kimunyu                           0.000305
# Barabara 8                        0.000305
# Headquarters                      0.000305
#                                     ...
# Mungoma Ya Chini                  0.000017
# Mwamanumbu                        0.000017
# Nkuasakuya                        0.000017
# Kwamsaje                          0.000017
# Rt                                0.000017
# Mapindunzi                        0.000017
# Bugoro                            0.000017
# Nagilongos                        0.000017
# Kisozoni                          0.000017
# Mwashimbi                         0.000017
# Changonde                         0.000017
# Keseria                           0.000017
# Manga Mashariki                   0.000017
# Mrunduka                          0.000017
# Mwijombe                          0.000017
# Namba 1                           0.000017
# Kwesimu                           0.000017
# Sagusa                            0.000017
# Namikurumo                        0.000017
# Bagaraa                           0.000017
# Chang'Anga                        0.000017
# Sumikombela                       0.000017
# Mwamungoya                        0.000017
# Mwaigoga                          0.000017
# Pemba Pwani                       0.000017
# Ikingulla                         0.000017
# Mwamakumbinb                      0.000017
# Usimba D                          0.000017
# Makurumo                          0.000017
# Kondo                             0.000017
# Isagenghe                         0.000017
# Ilanzi                            0.000017
# Seza Kijijini                     0.000017
# Inteki                            0.000017
# Bugomwa                           0.000017
# Sie                               0.000017
# Chipapa B                         0.000017
# Kijenge Juu                       0.000017
# Ndwita                            0.000017
# Mwembengozi                       0.000017
# Sezi                              0.000017
# Burwani                           0.000017
# Nagasunga                         0.000017
# Kihowa                            0.000017
# Dimba                             0.000017
# Rutunguru Shuleni                 0.000017
# Nakawele A                        0.000017
# Kwamianga                         0.000017
# Tetema                            0.000017
# Kabise                            0.000017
# Mishegiwela                       0.000017
# Mbuta Kusini                      0.000017
# Nzonze                            0.000017
# Chabundanga                       0.000017
# Igudija A                         0.000017
# Makanyo                           0.000017
# Fundikira                         0.000017
# Janukha                           0.000017
# Nyasaira                          0.000017
# Usei                              0.000017
# Bwageselewa                       0.000017
# Bwana Mzungu                      0.000017
# Silimka                           0.000017
# Likarangwa                        0.000017
# Injucha                           0.000017
# Masengwa                          0.000017
# Bukwimba                          0.000017
# Izugwabageni                      0.000017
# Mwansanga                         0.000017
# Qoriam                            0.000017
# Nyegina Kati                      0.000017
# Kibaya Kati                       0.000017
# Mkino                             0.000017
# Usitu                             0.000017
# Mwasute                           0.000017
# Ayamaami                          0.000017
# Msiondoke                         0.000017
# Kinyengesi                        0.000017
# Lungongole A                      0.000017
# Mbura                             0.000017
# Mwanhembo Centre                  0.000017
# Kishiri B                         0.000017
# Butini                            0.000017
# Nyamikingo                        0.000017
# Kanyakirere                       0.000017
# Sogeeni                           0.000017
# Chini Road                        0.000017
# Mwingiro B                        0.000017
# Kibogozi                          0.000017
# Kibupuni                          0.000017
# Mtonya B                          0.000017
# Bogogwa                           0.000017
# Mbatamela                         0.000017
# Sukutu                            0.000017
# Isagehe                           0.000017
# Kwaduri                           0.000017
# Kirimbochoni                      0.000017
# Kafika                            0.000017
# Mwabagosha                        0.000017
# Kwabota                           0.000017
# Nabili                            0.000017
# Idimbo                            0.000017
# Mpinga                            0.000017
# Shimbwe Chini                     0.000017
# Namikiga                          0.000017
# Msangila                          0.000017
# Teacher`S Training College-Ttc    0.000017
# Festo Ntanyungu                   0.000017
# Ruaha Juu                         0.000017
# Mutoma                            0.000017
# Kipora                            0.000017
# Bugando Centre                    0.000017
# Mhugani                           0.000017
# Mwashimbai A                      0.000017
# Muhutwe                           0.000017
# Udeghe                            0.000017
# Iselembeke                        0.000017
# Masoroha                          0.000017
# Budati                            0.000017
# Nyachonga                         0.000017
# Nyachumwi                         0.000017
# Luhila Kati                       0.000017
# Nyang'Anga B                      0.000017
# Kitengeni                         0.000017
# Kuliyandi                         0.000017
# Kisala                            0.000017
# Ichwankima A                      0.000017
# Ndolale                           0.000017
# Chandago                          0.000017
# Zindukeni                         0.000017
# Kishoko                           0.000017
# Kasuhilo                          0.000017
# Isunuka B                         0.000017
# Mwayole                           0.000017
# Orkesumet                         0.000017
# Usasi                             0.000017
# Ulowa No.2                        0.000017
# Omukitembe                        0.000017
# Barabara Ya 9                     0.000017
# Miondo                            0.000017
# Unyiru                            0.000017
# Kwa Missfumo                      0.000017
# Dioto                             0.000017
# Chonyonyo A                       0.000017
# Mwamakwale                        0.000017
# Bujagiji                          0.000017
# Movu Kati                         0.000017
# Gwelo Kaya                        0.000017
# 'A' Kati                          0.000017
# Pentekoste                        0.000017
# Njagu                             0.000017
# Ishongo Kati                      0.000017
# Wendahi                           0.000017
# Migutu                            0.000017
# Girango                           0.000017
# Kanyamanza A                      0.000017
# Lukali                            0.000017
# Mkwete B                          0.000017
# Makumbusho B                      0.000017
# Majengo Majarubani                0.000017
# Nyakazolo                         0.000017
# Mkwatani                          0.000017
# Matene                            0.000017
# Mtindiro Centre                   0.000017
# Kumshindwi B                      0.000017
# Iduya A                           0.000017
# Miputu                            0.000017
# Changawaka                        0.000017
# Mtemba                            0.000017
# Pongwe Kati                       0.000017
# Malongoni                         0.000017
# Butondolo                         0.000017
# Mchukwi A                         0.000017
# Ndono                             0.000017
# Engloriti                         0.000017
# Chamuralo                         0.000017
# Kankundane                        0.000017
# Muhola                            0.000017
# Kalimasumni                       0.000017
# Nyamkongoti                       0.000017
# Chiwachiwa                        0.000017
# Rwamitima                         0.000017
# Ngunjwa                           0.000017
# Tombola                           0.000017
# Nyanshigwe                        0.000017
# Kapollo                           0.000017
# Letaiyo                           0.000017
# Mukigende                         0.000017
# Milolakati                        0.000017
# Mdolela A                         0.000017
# Mkesa                             0.000017
# Ugayang'Ombe                      0.000017
# Chisale B                         0.000017
# Lutaru                            0.000017
# Mwamisiange                       0.000017
# Bandawe                           0.000017
# Sumbu                             0.000017
# Ikonongo                          0.000017
# Lungalunga                        0.000017
# Qanya                             0.000017
# Luang Bilo                        0.000017
# Nembora                           0.000017
# Milimbo                           0.000017
# Bweshamuzi                        0.000017
# Kambarage A                       0.000017
# Kinsengo                          0.000017
# Nampemba A                        0.000017
# Mkumba Mtoni                      0.000017
# Mkutuma                           0.000017
# Mtombozi                          0.000017
# Chenda                            0.000017
# Nyailungu                         0.000017
# Nyakararu                         0.000017
# Ukiwayuyu                         0.000017
# Mwansambo                         0.000017
# Buluga                            0.000017
# Lezaboni                          0.000017
# Bugarama Center                   0.000017
# Mpanda Mjini                      0.000017
# Ang'Atasere                       0.000017
# Amgera                            0.000017
# Kisokobe                          0.000017
# Mburumi                           0.000017
# Chini Dukani                      0.000017
# Nyangokolwa                       0.000017
# Bulyamuru                         0.000017
# Dengemaya                         0.000017
# Senje                             0.000017
# Mukitangaro                       0.000017
# Bassotu 'B'                       0.000017
# Kandashi Kati                     0.000017
# Mwanhala A                        0.000017
# Mnawa                             0.000017
# Nyamikoma A                       0.000017
# Makitiha                          0.000017
# Nyakahunga                        0.000017
# Nyambona                          0.000017
# Mhengelo                          0.000017
# Shibingo                          0.000017
# Mbage                             0.000017
# Buyanja                           0.000017
# Ruhindangoma                      0.000017
# Jasini                            0.000017
# Kwa                               0.000017
# Mkombi                            0.000017
# Lihiki A                          0.000017
# Galambo                           0.000017
# Manoshi                           0.000017
# Kaulangumi                        0.000017
# Mnembule                          0.000017
# Name: subvillage, Length: 19287, dtype: float64

# %%
df_categorical['subvillage'] = df_categorical['subvillage'].fillna(df_categorical['subvillage'].mode()[0])
df_categorical.isna().sum()
# Out:
# wpt_name                     0
# basin                        0
# subvillage                   0
# region                       0
# lga                          0
# ward                         0
# public_meeting            3334
# recorded_by                  0
# scheme_management         3877
# scheme_name              28166
# permit                    3056
# extraction_type              0
# extraction_type_group        0
# extraction_type_class        0
# management                   0
# management_group             0
# payment                      0
# payment_type                 0
# water_quality                0
# quality_group                0
# quantity                     0
# quantity_group               0
# source                       0
# source_type                  0
# source_class                 0
# waterpoint_type              0
# waterpoint_type_group        0
# id                           0
# target                       0
# funder_cleaned               0
# installer_cleaned            0
# dtype: int64

# %%
df_categorical['public_meeting'].value_counts(normalize=True)
# Out:
# True     0.909838
# False    0.090162
# Name: public_meeting, dtype: float64

# %%
df_categorical['public_meeting'] = df_categorical['public_meeting'].fillna(df_categorical['public_meeting'].mode()[0])
df_categorical.isna().sum()
# Out:
# wpt_name                     0
# basin                        0
# subvillage                   0
# region                       0
# lga                          0
# ward                         0
# public_meeting               0
# recorded_by                  0
# scheme_management         3877
# scheme_name              28166
# permit                    3056
# extraction_type              0
# extraction_type_group        0
# extraction_type_class        0
# management                   0
# management_group             0
# payment                      0
# payment_type                 0
# water_quality                0
# quality_group                0
# quantity                     0
# quantity_group               0
# source                       0
# source_type                  0
# source_class                 0
# waterpoint_type              0
# waterpoint_type_group        0
# id                           0
# target                       0
# funder_cleaned               0
# installer_cleaned            0
# dtype: int64

# %%
df_categorical['scheme_management'].value_counts(normalize=True)
# Out:
# VWC                 0.662662
# WUG                 0.093763
# Water authority     0.056787
# WUA                 0.051924
# Water Board         0.049493
# Parastatal          0.030258
# Private operator    0.019145
# Company             0.019109
# Other               0.013796
# SWC                 0.001747
# Trust               0.001297
# None                0.000018
# Name: scheme_management, dtype: float64

# %%
scheme_management_cleaned = []

for row in df_categorical['scheme_management']:
    if row == 'VWC':
        scheme_management_cleaned.append('VWC')
    else:
        scheme_management_cleaned.append('Other')
        
df_categorical['scheme_management_cleaned'] = scheme_management_cleaned

# %%
df_categorical = df_categorical.drop('scheme_management', axis=1)

# %%
df_categorical.head()
# Out:
#                wpt_name                    basin  subvillage   region        lga        ward  public_meeting              recorded_by                  scheme_name permit extraction_type extraction_type_group extraction_type_class management management_group         payment payment_type water_quality quality_group      quantity quantity_group                source           source_type source_class              waterpoint_type waterpoint_type_group     id          target funder_cleaned installer_cleaned scheme_management_cleaned
# 0                  none               Lake Nyasa    Mnyusi B   Iringa     Ludewa    Mundindi            True  GeoData Consultants Ltd                        Roman  False         gravity               gravity               gravity        vwc       user-group    pay annually     annually          soft          good        enough         enough                spring                spring  groundwater           communal standpipe    communal standpipe  69572      functional          Other             Other                       VWC
# 1              Zahanati            Lake Victoria     Nyamara     Mara  Serengeti       Natta            True  GeoData Consultants Ltd                          NaN   True         gravity               gravity               gravity        wug       user-group       never pay    never pay          soft          good  insufficient   insufficient  rainwater harvesting  rainwater harvesting      surface           communal standpipe    communal standpipe   8776      functional          Other             Other                     Other
# 2           Kwa Mahundi                  Pangani     Majengo  Manyara  Simanjiro     Ngorika            True  GeoData Consultants Ltd  Nyumba ya mungu pipe scheme   True         gravity               gravity               gravity        vwc       user-group  pay per bucket   per bucket          soft          good        enough         enough                   dam                   dam      surface  communal standpipe multiple    communal standpipe  34310      functional          Other             Other                       VWC
# 3  Zahanati Ya Nanyumbu  Ruvuma / Southern Coast  Mahakamani   Mtwara   Nanyumbu    Nanyumbu            True  GeoData Consultants Ltd                          NaN   True     submersible           submersible           submersible        vwc       user-group       never pay    never pay          soft          good           dry            dry           machine dbh              borehole  groundwater  communal standpipe multiple    communal standpipe  67743  non functional          Other             Other                       VWC
# 4               Shuleni            Lake Victoria  Kyanyamisa   Kagera    Karagwe  Nyakasimbi            True  GeoData Consultants Ltd                          NaN   True         gravity               gravity               gravity      other            other       never pay    never pay          soft          good      seasonal       seasonal  rainwater harvesting  rainwater harvesting      surface           communal standpipe    communal standpipe  19728      functional          Other             Other                     Other

# %%
df_categorical.isna().sum()
# Out:
# wpt_name                         0
# basin                            0
# subvillage                       0
# region                           0
# lga                              0
# ward                             0
# public_meeting                   0
# recorded_by                      0
# scheme_name                  28166
# permit                        3056
# extraction_type                  0
# extraction_type_group            0
# extraction_type_class            0
# management                       0
# management_group                 0
# payment                          0
# payment_type                     0
# water_quality                    0
# quality_group                    0
# quantity                         0
# quantity_group                   0
# source                           0
# source_type                      0
# source_class                     0
# waterpoint_type                  0
# waterpoint_type_group            0
# id                               0
# target                           0
# funder_cleaned                   0
# installer_cleaned                0
# scheme_management_cleaned        0
# dtype: int64

# %%
df_categorical = df_categorical.drop('scheme_name', axis=1)
df_categorical.head()
# Out:
#                wpt_name                    basin  subvillage   region        lga        ward  public_meeting              recorded_by permit extraction_type extraction_type_group extraction_type_class management management_group         payment payment_type water_quality quality_group      quantity quantity_group                source           source_type source_class              waterpoint_type waterpoint_type_group     id          target funder_cleaned installer_cleaned scheme_management_cleaned
# 0                  none               Lake Nyasa    Mnyusi B   Iringa     Ludewa    Mundindi            True  GeoData Consultants Ltd  False         gravity               gravity               gravity        vwc       user-group    pay annually     annually          soft          good        enough         enough                spring                spring  groundwater           communal standpipe    communal standpipe  69572      functional          Other             Other                       VWC
# 1              Zahanati            Lake Victoria     Nyamara     Mara  Serengeti       Natta            True  GeoData Consultants Ltd   True         gravity               gravity               gravity        wug       user-group       never pay    never pay          soft          good  insufficient   insufficient  rainwater harvesting  rainwater harvesting      surface           communal standpipe    communal standpipe   8776      functional          Other             Other                     Other
# 2           Kwa Mahundi                  Pangani     Majengo  Manyara  Simanjiro     Ngorika            True  GeoData Consultants Ltd   True         gravity               gravity               gravity        vwc       user-group  pay per bucket   per bucket          soft          good        enough         enough                   dam                   dam      surface  communal standpipe multiple    communal standpipe  34310      functional          Other             Other                       VWC
# 3  Zahanati Ya Nanyumbu  Ruvuma / Southern Coast  Mahakamani   Mtwara   Nanyumbu    Nanyumbu            True  GeoData Consultants Ltd   True     submersible           submersible           submersible        vwc       user-group       never pay    never pay          soft          good           dry            dry           machine dbh              borehole  groundwater  communal standpipe multiple    communal standpipe  67743  non functional          Other             Other                       VWC
# 4               Shuleni            Lake Victoria  Kyanyamisa   Kagera    Karagwe  Nyakasimbi            True  GeoData Consultants Ltd   True         gravity               gravity               gravity      other            other       never pay    never pay          soft          good      seasonal       seasonal  rainwater harvesting  rainwater harvesting      surface           communal standpipe    communal standpipe  19728      functional          Other             Other                     Other

# %%
df_categorical.isna().sum()
# Out:
# wpt_name                        0
# basin                           0
# subvillage                      0
# region                          0
# lga                             0
# ward                            0
# public_meeting                  0
# recorded_by                     0
# permit                       3056
# extraction_type                 0
# extraction_type_group           0
# extraction_type_class           0
# management                      0
# management_group                0
# payment                         0
# payment_type                    0
# water_quality                   0
# quality_group                   0
# quantity                        0
# quantity_group                  0
# source                          0
# source_type                     0
# source_class                    0
# waterpoint_type                 0
# waterpoint_type_group           0
# id                              0
# target                          0
# funder_cleaned                  0
# installer_cleaned               0
# scheme_management_cleaned       0
# dtype: int64

# %%
df_categorical['permit'].value_counts(normalize=True)
# Out:
# True     0.68955
# False    0.31045
# Name: permit, dtype: float64

# %%
df_categorical['permit'].head(120)
# Out:
# 0      False
# 1       True
# 2       True
# 3       True
# 4       True
# 5       True
# 6       True
# 7       True
# 8       True
# 9       True
# 10     False
# 11     False
# 12     False
# 13      True
# 14      True
# 15     False
# 16      True
# 17      True
# 18      True
# 19      True
# 20     False
# 21     False
# 22      True
# 23      True
# 24      True
# 25      True
# 26     False
# 27      True
# 28      True
# 29      True
# 30      True
# 31      True
# 32      True
# 33     False
# 34     False
# 35      True
# 36      True
# 37     False
# 38      True
# 39     False
# 40      True
# 41     False
# 42      True
# 43       NaN
# 44      True
# 45      True
# 46      True
# 47       NaN
# 48      True
# 49      True
# 50      True
# 51      True
# 52      True
# 53      True
# 54      True
# 55      True
# 56      True
# 57      True
# 58      True
# 59      True
# 60     False
# 61      True
# 62      True
# 63      True
# 64      True
# 65       NaN
# 66      True
# 67      True
# 68      True
# 69     False
# 70      True
# 71     False
# 72      True
# 73      True
# 74     False
# 75     False
# 76      True
# 77      True
# 78     False
# 79      True
# 80     False
# 81      True
# 82      True
# 83     False
# 84     False
# 85      True
# 86      True
# 87     False
# 88      True
# 89     False
# 90      True
# 91      True
# 92      True
# 93      True
# 94      True
# 95      True
# 96     False
# 97      True
# 98      True
# 99     False
# 100     True
# 101     True
# 102    False
# 103    False
# 104     True
# 105     True
# 106    False
# 107     True
# 108     True
# 109      NaN
# 110     True
# 111     True
# 112     True
# 113    False
# 114     True
# 115     True
# 116     True
# 117    False
# 118      NaN
# 119     True
# Name: permit, dtype: object

# %%
df_categorical['permit'] = df_categorical['permit'].replace('NaN', 'False')
df_categorical['permit'].value_counts(normalize=True)
# Out:
# True     0.68955
# False    0.31045
# Name: permit, dtype: float64

# %%
df_categorical.isna().sum()
# Out:
# wpt_name                        0
# basin                           0
# subvillage                      0
# region                          0
# lga                             0
# ward                            0
# public_meeting                  0
# recorded_by                     0
# permit                       3056
# extraction_type                 0
# extraction_type_group           0
# extraction_type_class           0
# management                      0
# management_group                0
# payment                         0
# payment_type                    0
# water_quality                   0
# quality_group                   0
# quantity                        0
# quantity_group                  0
# source                          0
# source_type                     0
# source_class                    0
# waterpoint_type                 0
# waterpoint_type_group           0
# id                              0
# target                          0
# funder_cleaned                  0
# installer_cleaned               0
# scheme_management_cleaned       0
# dtype: int64

# %%
df_categorical.dtypes
# Out:
# wpt_name                     object
# basin                        object
# subvillage                   object
# region                       object
# lga                          object
# ward                         object
# public_meeting                 bool
# recorded_by                  object
# permit                       object
# extraction_type              object
# extraction_type_group        object
# extraction_type_class        object
# management                   object
# management_group             object
# payment                      object
# payment_type                 object
# water_quality                object
# quality_group                object
# quantity                     object
# quantity_group               object
# source                       object
# source_type                  object
# source_class                 object
# waterpoint_type              object
# waterpoint_type_group        object
# id                            int64
# target                       object
# funder_cleaned               object
# installer_cleaned            object
# scheme_management_cleaned    object
# dtype: object

# %%
# full.permit.fillna(full.permit.describe().top,inplace = True)
# The .replace method did not work for this

df_categorical['permit'].fillna(df_categorical['permit'].describe().top, inplace=True)

# %%
df_categorical.isna().sum()
# Out:
# wpt_name                     0
# basin                        0
# subvillage                   0
# region                       0
# lga                          0
# ward                         0
# public_meeting               0
# recorded_by                  0
# permit                       0
# extraction_type              0
# extraction_type_group        0
# extraction_type_class        0
# management                   0
# management_group             0
# payment                      0
# payment_type                 0
# water_quality                0
# quality_group                0
# quantity                     0
# quantity_group               0
# source                       0
# source_type                  0
# source_class                 0
# waterpoint_type              0
# waterpoint_type_group        0
# id                           0
# target                       0
# funder_cleaned               0
# installer_cleaned            0
# scheme_management_cleaned    0
# dtype: int64

# %%
df_categorical.shape
# Out:
# (59400, 30)

# %%
df_categorical.head()
# Out:
#                wpt_name                    basin  subvillage   region        lga        ward  public_meeting              recorded_by  permit extraction_type extraction_type_group extraction_type_class management management_group         payment payment_type water_quality quality_group      quantity quantity_group                source           source_type source_class              waterpoint_type waterpoint_type_group     id          target funder_cleaned installer_cleaned scheme_management_cleaned
# 0                  none               Lake Nyasa    Mnyusi B   Iringa     Ludewa    Mundindi            True  GeoData Consultants Ltd   False         gravity               gravity               gravity        vwc       user-group    pay annually     annually          soft          good        enough         enough                spring                spring  groundwater           communal standpipe    communal standpipe  69572      functional          Other             Other                       VWC
# 1              Zahanati            Lake Victoria     Nyamara     Mara  Serengeti       Natta            True  GeoData Consultants Ltd    True         gravity               gravity               gravity        wug       user-group       never pay    never pay          soft          good  insufficient   insufficient  rainwater harvesting  rainwater harvesting      surface           communal standpipe    communal standpipe   8776      functional          Other             Other                     Other
# 2           Kwa Mahundi                  Pangani     Majengo  Manyara  Simanjiro     Ngorika            True  GeoData Consultants Ltd    True         gravity               gravity               gravity        vwc       user-group  pay per bucket   per bucket          soft          good        enough         enough                   dam                   dam      surface  communal standpipe multiple    communal standpipe  34310      functional          Other             Other                       VWC
# 3  Zahanati Ya Nanyumbu  Ruvuma / Southern Coast  Mahakamani   Mtwara   Nanyumbu    Nanyumbu            True  GeoData Consultants Ltd    True     submersible           submersible           submersible        vwc       user-group       never pay    never pay          soft          good           dry            dry           machine dbh              borehole  groundwater  communal standpipe multiple    communal standpipe  67743  non functional          Other             Other                       VWC
# 4               Shuleni            Lake Victoria  Kyanyamisa   Kagera    Karagwe  Nyakasimbi            True  GeoData Consultants Ltd    True         gravity               gravity               gravity      other            other       never pay    never pay          soft          good      seasonal       seasonal  rainwater harvesting  rainwater harvesting      surface           communal standpipe    communal standpipe  19728      functional          Other             Other                     Other

# %%
df_categorical['funder_cleaned'].value_counts(normalize=True)
# Out:
# Other       0.785875
# Tanzania    0.214125
# Name: funder_cleaned, dtype: float64

# %%
df_categorical['installer_cleaned'].value_counts(normalize=True)
# Out:
# Other    0.707037
# DWE      0.292963
# Name: installer_cleaned, dtype: float64

# %%
df_categorical.drop('wpt_name', axis=1, inplace=True)
df_categorical.head()
# Out:
#                      basin  subvillage   region        lga        ward  public_meeting              recorded_by  permit extraction_type extraction_type_group extraction_type_class management management_group         payment payment_type water_quality quality_group      quantity quantity_group                source           source_type source_class              waterpoint_type waterpoint_type_group     id          target funder_cleaned installer_cleaned scheme_management_cleaned
# 0               Lake Nyasa    Mnyusi B   Iringa     Ludewa    Mundindi            True  GeoData Consultants Ltd   False         gravity               gravity               gravity        vwc       user-group    pay annually     annually          soft          good        enough         enough                spring                spring  groundwater           communal standpipe    communal standpipe  69572      functional          Other             Other                       VWC
# 1            Lake Victoria     Nyamara     Mara  Serengeti       Natta            True  GeoData Consultants Ltd    True         gravity               gravity               gravity        wug       user-group       never pay    never pay          soft          good  insufficient   insufficient  rainwater harvesting  rainwater harvesting      surface           communal standpipe    communal standpipe   8776      functional          Other             Other                     Other
# 2                  Pangani     Majengo  Manyara  Simanjiro     Ngorika            True  GeoData Consultants Ltd    True         gravity               gravity               gravity        vwc       user-group  pay per bucket   per bucket          soft          good        enough         enough                   dam                   dam      surface  communal standpipe multiple    communal standpipe  34310      functional          Other             Other                       VWC
# 3  Ruvuma / Southern Coast  Mahakamani   Mtwara   Nanyumbu    Nanyumbu            True  GeoData Consultants Ltd    True     submersible           submersible           submersible        vwc       user-group       never pay    never pay          soft          good           dry            dry           machine dbh              borehole  groundwater  communal standpipe multiple    communal standpipe  67743  non functional          Other             Other                       VWC
# 4            Lake Victoria  Kyanyamisa   Kagera    Karagwe  Nyakasimbi            True  GeoData Consultants Ltd    True         gravity               gravity               gravity      other            other       never pay    never pay          soft          good      seasonal       seasonal  rainwater harvesting  rainwater harvesting      surface           communal standpipe    communal standpipe  19728      functional          Other             Other                     Other

# %%
df_categorical['lga'].value_counts(normalize=True)
# Out:
# Njombe              0.042138
# Arusha Rural        0.021077
# Moshi Rural         0.021061
# Bariadi             0.019815
# Rungwe              0.018620
# Kilosa              0.018418
# Kasulu              0.017626
# Mbozi               0.017407
# Meru                0.016987
# Bagamoyo            0.016785
# Singida Rural       0.016751
# Kilombero           0.016145
# Same                0.014764
# Kibondo             0.014714
# Kyela               0.014461
# Kahama              0.014074
# Magu                0.013872
# Kigoma Rural        0.013872
# Maswa               0.013620
# Karagwe             0.012980
# Mbinga              0.012626
# Iringa Rural        0.012256
# Serengeti           0.012054
# Namtumbo            0.011684
# Lushoto             0.011684
# Songea Rural        0.011667
# Mpanda              0.011431
# Mvomero             0.011296
# Ngara               0.011263
# Ulanga              0.011195
# Makete              0.010606
# Kwimba              0.010556
# Mbarali             0.010539
# Hai                 0.010522
# Rombo               0.010000
# Shinyanga Rural     0.009899
# Nzega               0.009680
# Ludewa              0.009495
# Mkuranga            0.009428
# Iramba              0.009158
# Masasi              0.008889
# Kondoa              0.008805
# Sumbawanga Rural    0.008771
# Morogoro Rural      0.008771
# Mufindi             0.008754
# Mwanga              0.008737
# Bukombe             0.008653
# Babati              0.008603
# Ilala               0.008367
# Geita               0.008215
# Bukoba Rural        0.008199
# Mbeya Rural         0.008165
# Meatu               0.007879
# Rufiji              0.007643
# Bunda               0.007374
# Siha                0.007306
# Nkasi               0.007205
# Tunduru             0.007121
# Mtwara Rural        0.007121
# Korogwe             0.006936
# Biharamulo          0.006785
# Muleba              0.006768
# Kishapu             0.006717
# Musoma Rural        0.006667
# Kilwa               0.006599
# Lindi Rural         0.006532
# Mpwapwa             0.006532
# Urambo              0.006431
# Manyoni             0.006347
# Kongwa              0.006077
# Dodoma Urban        0.006027
# Kilolo              0.005875
# Missungwi           0.005859
# Chamwino            0.005842
# Ukerewe             0.005741
# Uyui                0.005707
# Igunga              0.005690
# Muheza              0.005623
# Sengerema           0.005572
# Karatu              0.005488
# Longido             0.005219
# Simanjiro           0.005185
# Pangani             0.005135
# Nachingwea          0.005051
# Chunya              0.005017
# Mbulu               0.005000
# Ruangwa             0.004899
# Mkinga              0.004848
# Hanang              0.004613
# Kibaha              0.004529
# Tandahimba          0.004478
# Misenyi             0.004377
# Handeni             0.004276
# Chato               0.003973
# Newala              0.003889
# Ileje               0.003889
# Bahi                0.003771
# Kisarawe            0.003754
# Temeke              0.003620
# Rorya               0.003535
# Tarime              0.003519
# Ngorongoro          0.003384
# Kiteto              0.003249
# Shinyanga Urban     0.003215
# Monduli             0.003182
# Sumbawanga Urban    0.003030
# Singida Urban       0.002980
# Sikonge             0.002862
# Kilindi             0.002710
# Nanyumbu            0.002660
# Tabora Urban        0.002609
# Liwale              0.002593
# Ilemela             0.002391
# Mafia               0.002222
# Mtwara Urban        0.002088
# Tanga               0.001667
# Morogoro Urban      0.001616
# Kinondoni           0.001566
# Bukoba Urban        0.001481
# Songea Urban        0.001347
# Moshi Urban         0.001330
# Kigoma Urban        0.001195
# Arusha Urban        0.001061
# Lindi Urban         0.000354
# Nyamagana           0.000017
# Name: lga, dtype: float64

# %%
df_categorical['region'].value_counts(normalize=True)
# Out:
# Iringa           0.089125
# Shinyanga        0.083872
# Mbeya            0.078098
# Kilimanjaro      0.073721
# Morogoro         0.067441
# Arusha           0.056397
# Kagera           0.055825
# Mwanza           0.052222
# Kigoma           0.047407
# Ruvuma           0.044444
# Pwani            0.044360
# Tanga            0.042879
# Dodoma           0.037054
# Singida          0.035236
# Mara             0.033148
# Tabora           0.032980
# Rukwa            0.030438
# Mtwara           0.029125
# Manyara          0.026650
# Lindi            0.026027
# Dar es Salaam    0.013552
# Name: region, dtype: float64

# %%
df_categorical['ward'].value_counts(normalize=True)
# Out:
# Igosi                      0.005168
# Imalinyi                   0.004242
# Siha Kati                  0.003906
# Mdandu                     0.003889
# Nduruma                    0.003653
# Kitunda                    0.003418
# Mishamo                    0.003418
# Msindo                     0.003384
# Chalinze                   0.003300
# Maji ya Chai               0.003199
# Usuka                      0.003148
# Ngarenanyuki               0.002896
# Chanika                    0.002879
# Vikindu                    0.002727
# Mtwango                    0.002576
# Matola                     0.002441
# Zinga/Ikerege              0.002374
# Wanging'ombe               0.002340
# Maramba                    0.002340
# Itete                      0.002306
# Magomeni                   0.002273
# Kikatiti                   0.002256
# Ifakara                    0.002256
# Olkokola                   0.002239
# Maposeni                   0.002189
# Mvomero                    0.002172
# Igongolo                   0.002172
# Mlangali                   0.002104
# Nkoma                      0.002054
# Mahongole                  0.002037
# Nkungulu                   0.002037
# Rujewa                     0.002020
# Simbo                      0.001987
# Masama Magharibi           0.001953
# Mamire                     0.001936
# Kiranyi                    0.001936
# Kidatu                     0.001919
# Lupalilo                   0.001919
# Kagongo                    0.001902
# Ihanda                     0.001902
# Hedaru                     0.001886
# Chinamili                  0.001869
# Isongole                   0.001835
# Siha Mashariki             0.001835
# Masama Mashariki           0.001801
# Mkongo                     0.001801
# Makuyuni                   0.001785
# Yombo                      0.001785
# Tinde                      0.001785
# Kanga                      0.001768
# Bugarama                   0.001751
# Makwale                    0.001751
# Kimochi                    0.001751
# Malindi                    0.001734
# Soga                       0.001734
# Diongoya                   0.001734
# Mabwerebwere               0.001717
# Mahembe                    0.001700
# Kibaoni                    0.001650
# Kirua Vunjo Kusini         0.001650
# Leguruki                   0.001633
# Ilolangulu                 0.001616
# Lembeni                    0.001599
# Ruhembe                    0.001599
# Bungu                      0.001566
# Ruanda                     0.001566
# Mlangarini                 0.001549
# Mhunze                     0.001549
# Mang'ula                   0.001532
# Kakonko                    0.001515
# Mlali                      0.001515
# Uwemba                     0.001498
# Rusumo                     0.001498
# Lumemo                     0.001498
# Kifanya                    0.001481
# Chimala                    0.001481
# Magagura                   0.001465
# Munyegera                  0.001465
# Ipande                     0.001465
# Kisesa                     0.001465
# Kenyamonta                 0.001465
# Ilkiding'a                 0.001448
# Chanzuru                   0.001448
# Ubaruku                    0.001448
# Mbulumbulu                 0.001448
# Murufiti                   0.001448
# Wino                       0.001431
# Matendo                    0.001431
# Mkula                      0.001414
# Muzye                      0.001414
# Muhinda                    0.001397
# Mapogoro                   0.001397
# Lupembe                    0.001397
# Mpuguso                    0.001397
# Kibosho Magharibi          0.001380
# Keni Mengeni               0.001364
# Msia                       0.001364
# Nyimbili                   0.001364
# Manyoni                    0.001347
# Busole                     0.001347
# Nkololo                    0.001347
# Ilima                      0.001330
# Kidodi                     0.001330
# Kimnyaki                   0.001330
# Ushirombo                  0.001296
# Rungwe Mpya                0.001296
# Oldonyosambu               0.001296
# Igurusi                    0.001296
# Machame Uroki              0.001279
# Kirongwe                   0.001279
# Lugoba                     0.001279
# Oltroto                    0.001263
# Lupata                     0.001263
# Nyakitonto                 0.001263
# Mbuyuni                    0.001263
# Kiwira                     0.001246
# Lupila                     0.001246
# Nkwenda                    0.001246
# Bumera                     0.001246
# Ipililo                    0.001246
# Luegu                      0.001246
# Ruhita                     0.001246
# Chakwale                   0.001246
# Boma la ng'ombe            0.001246
# Ulenje                     0.001229
# Msata                      0.001229
# Samuye                     0.001229
# Mwandoya                   0.001229
# Kyimo                      0.001229
# Mwaya                      0.001229
# Pugu                       0.001229
# Malinyi                    0.001212
# Mbwewe                     0.001212
# King'ori                   0.001212
# Isandula                   0.001212
# Somanda                    0.001212
# Mkalamo                    0.001195
# Natta                      0.001195
# Lufingo                    0.001195
# Busilili                   0.001178
# Ilembula                   0.001178
# Hembeti                    0.001178
# Mlimba                     0.001178
# Rusesa                     0.001178
# Kihorogota                 0.001178
# Isansa                     0.001162
# Rugongowe                  0.001162
# Sakasaka                   0.001162
# Njoro                      0.001162
# Lwangwa                    0.001162
# Machame Kusini             0.001162
# Machame Kaskazini          0.001145
# Mtinko                     0.001145
# Mpitimbi                   0.001145
# Kalinzi                    0.001145
# Ketumbeine                 0.001145
# Ushirika                   0.001145
# Ukumbi                     0.001128
# Ihanja                     0.001128
# Iyula                      0.001128
# Ikolo                      0.001128
# Olmolog                    0.001111
# Kibondo Urban              0.001111
# Kalangalala                0.001111
# Kileo                      0.001111
# Nyarubungo                 0.001111
# Mwagi                      0.001111
# Namabengo                  0.001111
# Lutebe                     0.001094
# Ikuka                      0.001094
# Chala                      0.001094
# Nyamuswa                   0.001094
# Utete                      0.001094
# Janda                      0.001077
# Munga'a                    0.001077
# Pangani Mashariki          0.001077
# Namanyere                  0.001077
# Namajani                   0.001077
# Madilu                     0.001077
# Namanga                    0.001077
# Kassambya                  0.001077
# Mugumu Urban               0.001077
# Mpindo                     0.001077
# Biharamulo Urban           0.001061
# Myangayanga                0.001061
# Itaka                      0.001061
# Esilalei                   0.001061
# Makambako                  0.001061
# Qurus                      0.001061
# Ilongero                   0.001061
# Lusungo                    0.001044
# Mseke                      0.001044
# Salawe                     0.001044
# Matema                     0.001044
# Ipinda                     0.001044
# Nyololo                    0.001027
# Matimira                   0.001027
# Kahe                       0.001027
# Buchambi                   0.001027
# Lagangabilili              0.001027
# Katumba                    0.001027
# Mang'oto                   0.001027
# Mshewa                     0.001010
# Kibimba                    0.001010
# Sukuma                     0.001010
# Ngerengere                 0.001010
# Mwamala                    0.001010
# Endabash                   0.001010
# Ikungu                     0.001010
# Dumila                     0.001010
# Mamba                      0.001010
# Kisanga                    0.001010
# Kwakoa                     0.000993
# Kibiti                     0.000993
# Malolo                     0.000993
# Mwaniko                    0.000993
# Igalula                    0.000993
# Shume                      0.000993
# Machame Mashariki          0.000993
# Bujashi                    0.000993
# Kwai                       0.000993
# Madibira                   0.000976
# Msongola                   0.000976
# Kiruruma                   0.000976
# Kisemu                     0.000976
# Sanje                      0.000976
# Masange                    0.000976
# Siha Kaskazini             0.000976
# Lulindi                    0.000976
# Mwika Kusini               0.000960
# Ndalambo                   0.000960
# Arusha Chini               0.000960
# Busagara                   0.000960
# Mabamba                    0.000960
# Ikunguigazi                0.000960
# Lukulendi                  0.000960
# Mbebe                      0.000960
# Nambinzo                   0.000960
# Usanda                     0.000960
# Mawengi                    0.000960
# Mtimbira                   0.000943
# Image                      0.000943
# Lufilyo                    0.000943
# Runazi                     0.000943
# Bonde la Songwe            0.000943
# Kiromo                     0.000943
# Ntobeye                    0.000943
# Luduga                     0.000943
# Nsimbo                     0.000943
# Liuli                      0.000926
#                              ...
# Moita                      0.000101
# Kiluvya                    0.000101
# Cholesamvula               0.000101
# Nyarokoba                  0.000101
# Mubunda                    0.000101
# Langiro                    0.000101
# Nanyamba                   0.000101
# Lwamgasa                   0.000101
# Buzilasoga                 0.000101
# Mindu                      0.000101
# Stesheni                   0.000101
# Dunda                      0.000101
# Mwese                      0.000101
# Ngulu                      0.000101
# Vumilia                    0.000101
# Ngasamo                    0.000101
# Kambikatoto                0.000101
# Kimbe                      0.000101
# Milingoti Magharibi        0.000101
# Kyamuraile                 0.000101
# Kibasuka                   0.000101
# Usevya                     0.000101
# Malibwi                    0.000101
# Igandu                     0.000101
# Uyowa                      0.000101
# Myunga                     0.000101
# Magengati                  0.000101
# Mpamantwa                  0.000084
# Rau                        0.000084
# Nyakagomba                 0.000084
# Chikongola                 0.000084
# Litumbandyosi              0.000084
# Mwamishali                 0.000084
# Ichemba                    0.000084
# Bukiko                     0.000084
# Mkutano                    0.000084
# Kikomero                   0.000084
# Rubuga                     0.000084
# Mshangano                  0.000084
# Ushokola                   0.000084
# Mpinji                     0.000084
# Kisumwa                    0.000084
# Chuno                      0.000084
# Mhande                     0.000084
# Chali                      0.000084
# Oldonyo Sambu              0.000084
# Kabula                     0.000084
# Kamhanga                   0.000084
# Iyogwe                     0.000084
# Kiboriloni                 0.000084
# Makojo                     0.000084
# Bugwema                    0.000084
# Busanda                    0.000084
# Kaloleni                   0.000084
# Ihanamilo                  0.000084
# Nakatuguru                 0.000084
# Manzase                    0.000084
# Nditi                      0.000084
# Serengeti National Park    0.000084
# Bukwe                      0.000084
# Sirop                      0.000084
# Igigwa                     0.000084
# Talawanda                  0.000084
# Kitanga                    0.000084
# Mtanda                     0.000084
# Isanzu                     0.000084
# Gombero                    0.000084
# Itandula                   0.000084
# Mafyeko                    0.000084
# Minyughe                   0.000084
# Railway                    0.000084
# Gode Gode                  0.000084
# Nhundulu                   0.000084
# Milingoti Mashariki        0.000084
# Bubiki                     0.000084
# Itunduru                   0.000084
# Kanyenye                   0.000084
# Bwakila Juu                0.000084
# Katuma                     0.000084
# Marui                      0.000084
# Sombetini                  0.000067
# Mwanga Urban               0.000067
# Bukura                     0.000067
# Ng'haya                    0.000067
# Pangani Magharibi          0.000067
# Mbwara                     0.000067
# Kansay                     0.000067
# Ishunju                    0.000067
# Kinyala                    0.000067
# Nyugwa                     0.000067
# Itilo                      0.000067
# Kasimbu                    0.000067
# Shangani                   0.000067
# Maguu                      0.000067
# Uyui                       0.000067
# Vugiri                     0.000067
# Mtonya                     0.000067
# Kilimilire                 0.000067
# Machimboni                 0.000067
# Nangaru                    0.000067
# Langali                    0.000067
# Katandala                  0.000067
# Nyamunga                   0.000067
# Ilindi                     0.000067
# Mwangoi                    0.000067
# Olorien                    0.000067
# Matui                      0.000067
# Mhezi                      0.000067
# Sokon I                    0.000067
# Roche                      0.000067
# Manwanga                   0.000067
# Mvumi Mission              0.000067
# Bassodesh                  0.000067
# Kitura                     0.000067
# Oldeani                    0.000067
# Lemara                     0.000067
# Naiyobi                    0.000067
# Ipuli                      0.000051
# Santilya                   0.000051
# Lizaboni                   0.000051
# Nghambaku                  0.000051
# Mganza                     0.000051
# Daraja Mbili               0.000051
# Rusimbi                    0.000051
# Pangale                    0.000051
# Ng'ambo                    0.000051
# Chamazi                    0.000051
# Saunyi                     0.000051
# Magoroto                   0.000051
# Masasi                     0.000051
# Mpigamiti                  0.000051
# Goribe                     0.000051
# Namapwia                   0.000051
# Kawajense                  0.000051
# Tambuka Reli               0.000051
# Subira                     0.000051
# Kitangili                  0.000051
# Mbweni                     0.000051
# Mwashiku                   0.000051
# Kingerikiti                0.000051
# Ngarenaro                  0.000051
# Mazimbu                    0.000051
# Nangano                    0.000051
# Matwiga                    0.000051
# Mwembesongo                0.000051
# Isevya                     0.000051
# Shitage                    0.000051
# Masukulu                   0.000051
# Nangowe                    0.000051
# Sigili                     0.000051
# Ilujamate                  0.000051
# Changaa                    0.000051
# Mizibaziba                 0.000051
# Mcholi II                  0.000051
# Gongoni                    0.000051
# Sekei                      0.000051
# Rusaba                     0.000051
# Lubiri                     0.000051
# Kainam                     0.000051
# Jibondo                    0.000051
# Kakesio                    0.000051
# Kiusa                      0.000034
# Boma                       0.000034
# Nguvu Moja                 0.000034
# Heka Azimio                0.000034
# Kiyowela                   0.000034
# Fufu                       0.000034
# Bombambili                 0.000034
# Bukumi                     0.000034
# Shilalo                    0.000034
# Mwisi                      0.000034
# Itewe                      0.000034
# Mkwiti                     0.000034
# Kining'inila               0.000034
# Gitting                    0.000034
# Lutindi                    0.000034
# Isuto                      0.000034
# Laghanga                   0.000034
# Ijanija                    0.000034
# Baraa                      0.000034
# Kwasunga                   0.000034
# Membe                      0.000034
# Bukoko                     0.000034
# Kasiriri                   0.000034
# Chifunfu                   0.000034
# Gidahababieg               0.000034
# Kemambo                    0.000034
# Tunduma                    0.000034
# Kitembe                    0.000034
# Idodyandole                0.000034
# Bukondo                    0.000034
# Bondeni                    0.000034
# Ugala                      0.000034
# Vikumbulu                  0.000034
# Shabaka                    0.000034
# Salama                     0.000034
# Maskati                    0.000034
# Bureza                     0.000034
# Kimandolu                  0.000034
# Kimwani                    0.000034
# Misunkumilo                0.000034
# Magindu                    0.000034
# Mfaranyaki                 0.000034
# Budushi                    0.000034
# Manyondwe                  0.000034
# Semembela                  0.000034
# Levolosi                   0.000034
# Mkwajuni                   0.000034
# Luwalaje                   0.000034
# Murray                     0.000034
# Shigamba                   0.000034
# Negero                     0.000034
# Mkindi                     0.000034
# Pangwi                     0.000034
# Ilula                      0.000034
# Kimambi                    0.000034
# Nyanungu                   0.000034
# Tambukareli                0.000034
# Kapalala                   0.000034
# Nkome                      0.000034
# Ikweha                     0.000017
# Mkumbi                     0.000017
# Kapilula                   0.000017
# Burungura                  0.000017
# Kinungu                    0.000017
# Machinjioni                0.000017
# Igogo                      0.000017
# Kihangimahuka              0.000017
# Rasbura                    0.000017
# Thawi                      0.000017
# Themi                      0.000017
# Mlimani                    0.000017
# Ifinga                     0.000017
# Uwanja wa Ndege            0.000017
# Kirongo                    0.000017
# Nyamtinga                  0.000017
# Nsemulwa                   0.000017
# Ukata                      0.000017
# Korongoni                  0.000017
# Izia                       0.000017
# Matarawe                   0.000017
# Chinugulu                  0.000017
# Simbay                     0.000017
# Kitete                     0.000017
# Mawenzi                    0.000017
# Mwanga Kaskazini           0.000017
# Linda                      0.000017
# Sungwisi                   0.000017
# Mitole                     0.000017
# Uchindile                  0.000017
# Name: ward, Length: 2092, dtype: float64

# %%
df_categorical['ward'].value_counts(normalize=True)
# Out:
# Igosi                      0.005168
# Imalinyi                   0.004242
# Siha Kati                  0.003906
# Mdandu                     0.003889
# Nduruma                    0.003653
# Kitunda                    0.003418
# Mishamo                    0.003418
# Msindo                     0.003384
# Chalinze                   0.003300
# Maji ya Chai               0.003199
# Usuka                      0.003148
# Ngarenanyuki               0.002896
# Chanika                    0.002879
# Vikindu                    0.002727
# Mtwango                    0.002576
# Matola                     0.002441
# Zinga/Ikerege              0.002374
# Wanging'ombe               0.002340
# Maramba                    0.002340
# Itete                      0.002306
# Magomeni                   0.002273
# Kikatiti                   0.002256
# Ifakara                    0.002256
# Olkokola                   0.002239
# Maposeni                   0.002189
# Mvomero                    0.002172
# Igongolo                   0.002172
# Mlangali                   0.002104
# Nkoma                      0.002054
# Mahongole                  0.002037
# Nkungulu                   0.002037
# Rujewa                     0.002020
# Simbo                      0.001987
# Masama Magharibi           0.001953
# Mamire                     0.001936
# Kiranyi                    0.001936
# Kidatu                     0.001919
# Lupalilo                   0.001919
# Kagongo                    0.001902
# Ihanda                     0.001902
# Hedaru                     0.001886
# Chinamili                  0.001869
# Isongole                   0.001835
# Siha Mashariki             0.001835
# Masama Mashariki           0.001801
# Mkongo                     0.001801
# Makuyuni                   0.001785
# Yombo                      0.001785
# Tinde                      0.001785
# Kanga                      0.001768
# Bugarama                   0.001751
# Makwale                    0.001751
# Kimochi                    0.001751
# Malindi                    0.001734
# Soga                       0.001734
# Diongoya                   0.001734
# Mabwerebwere               0.001717
# Mahembe                    0.001700
# Kibaoni                    0.001650
# Kirua Vunjo Kusini         0.001650
# Leguruki                   0.001633
# Ilolangulu                 0.001616
# Lembeni                    0.001599
# Ruhembe                    0.001599
# Bungu                      0.001566
# Ruanda                     0.001566
# Mlangarini                 0.001549
# Mhunze                     0.001549
# Mang'ula                   0.001532
# Kakonko                    0.001515
# Mlali                      0.001515
# Uwemba                     0.001498
# Rusumo                     0.001498
# Lumemo                     0.001498
# Kifanya                    0.001481
# Chimala                    0.001481
# Magagura                   0.001465
# Munyegera                  0.001465
# Ipande                     0.001465
# Kisesa                     0.001465
# Kenyamonta                 0.001465
# Ilkiding'a                 0.001448
# Chanzuru                   0.001448
# Ubaruku                    0.001448
# Mbulumbulu                 0.001448
# Murufiti                   0.001448
# Wino                       0.001431
# Matendo                    0.001431
# Mkula                      0.001414
# Muzye                      0.001414
# Muhinda                    0.001397
# Mapogoro                   0.001397
# Lupembe                    0.001397
# Mpuguso                    0.001397
# Kibosho Magharibi          0.001380
# Keni Mengeni               0.001364
# Msia                       0.001364
# Nyimbili                   0.001364
# Manyoni                    0.001347
# Busole                     0.001347
# Nkololo                    0.001347
# Ilima                      0.001330
# Kidodi                     0.001330
# Kimnyaki                   0.001330
# Ushirombo                  0.001296
# Rungwe Mpya                0.001296
# Oldonyosambu               0.001296
# Igurusi                    0.001296
# Machame Uroki              0.001279
# Kirongwe                   0.001279
# Lugoba                     0.001279
# Oltroto                    0.001263
# Lupata                     0.001263
# Nyakitonto                 0.001263
# Mbuyuni                    0.001263
# Kiwira                     0.001246
# Lupila                     0.001246
# Nkwenda                    0.001246
# Bumera                     0.001246
# Ipililo                    0.001246
# Luegu                      0.001246
# Ruhita                     0.001246
# Chakwale                   0.001246
# Boma la ng'ombe            0.001246
# Ulenje                     0.001229
# Msata                      0.001229
# Samuye                     0.001229
# Mwandoya                   0.001229
# Kyimo                      0.001229
# Mwaya                      0.001229
# Pugu                       0.001229
# Malinyi                    0.001212
# Mbwewe                     0.001212
# King'ori                   0.001212
# Isandula                   0.001212
# Somanda                    0.001212
# Mkalamo                    0.001195
# Natta                      0.001195
# Lufingo                    0.001195
# Busilili                   0.001178
# Ilembula                   0.001178
# Hembeti                    0.001178
# Mlimba                     0.001178
# Rusesa                     0.001178
# Kihorogota                 0.001178
# Isansa                     0.001162
# Rugongowe                  0.001162
# Sakasaka                   0.001162
# Njoro                      0.001162
# Lwangwa                    0.001162
# Machame Kusini             0.001162
# Machame Kaskazini          0.001145
# Mtinko                     0.001145
# Mpitimbi                   0.001145
# Kalinzi                    0.001145
# Ketumbeine                 0.001145
# Ushirika                   0.001145
# Ukumbi                     0.001128
# Ihanja                     0.001128
# Iyula                      0.001128
# Ikolo                      0.001128
# Olmolog                    0.001111
# Kibondo Urban              0.001111
# Kalangalala                0.001111
# Kileo                      0.001111
# Nyarubungo                 0.001111
# Mwagi                      0.001111
# Namabengo                  0.001111
# Lutebe                     0.001094
# Ikuka                      0.001094
# Chala                      0.001094
# Nyamuswa                   0.001094
# Utete                      0.001094
# Janda                      0.001077
# Munga'a                    0.001077
# Pangani Mashariki          0.001077
# Namanyere                  0.001077
# Namajani                   0.001077
# Madilu                     0.001077
# Namanga                    0.001077
# Kassambya                  0.001077
# Mugumu Urban               0.001077
# Mpindo                     0.001077
# Biharamulo Urban           0.001061
# Myangayanga                0.001061
# Itaka                      0.001061
# Esilalei                   0.001061
# Makambako                  0.001061
# Qurus                      0.001061
# Ilongero                   0.001061
# Lusungo                    0.001044
# Mseke                      0.001044
# Salawe                     0.001044
# Matema                     0.001044
# Ipinda                     0.001044
# Nyololo                    0.001027
# Matimira                   0.001027
# Kahe                       0.001027
# Buchambi                   0.001027
# Lagangabilili              0.001027
# Katumba                    0.001027
# Mang'oto                   0.001027
# Mshewa                     0.001010
# Kibimba                    0.001010
# Sukuma                     0.001010
# Ngerengere                 0.001010
# Mwamala                    0.001010
# Endabash                   0.001010
# Ikungu                     0.001010
# Dumila                     0.001010
# Mamba                      0.001010
# Kisanga                    0.001010
# Kwakoa                     0.000993
# Kibiti                     0.000993
# Malolo                     0.000993
# Mwaniko                    0.000993
# Igalula                    0.000993
# Shume                      0.000993
# Machame Mashariki          0.000993
# Bujashi                    0.000993
# Kwai                       0.000993
# Madibira                   0.000976
# Msongola                   0.000976
# Kiruruma                   0.000976
# Kisemu                     0.000976
# Sanje                      0.000976
# Masange                    0.000976
# Siha Kaskazini             0.000976
# Lulindi                    0.000976
# Mwika Kusini               0.000960
# Ndalambo                   0.000960
# Arusha Chini               0.000960
# Busagara                   0.000960
# Mabamba                    0.000960
# Ikunguigazi                0.000960
# Lukulendi                  0.000960
# Mbebe                      0.000960
# Nambinzo                   0.000960
# Usanda                     0.000960
# Mawengi                    0.000960
# Mtimbira                   0.000943
# Image                      0.000943
# Lufilyo                    0.000943
# Runazi                     0.000943
# Bonde la Songwe            0.000943
# Kiromo                     0.000943
# Ntobeye                    0.000943
# Luduga                     0.000943
# Nsimbo                     0.000943
# Liuli                      0.000926
#                              ...
# Moita                      0.000101
# Kiluvya                    0.000101
# Cholesamvula               0.000101
# Nyarokoba                  0.000101
# Mubunda                    0.000101
# Langiro                    0.000101
# Nanyamba                   0.000101
# Lwamgasa                   0.000101
# Buzilasoga                 0.000101
# Mindu                      0.000101
# Stesheni                   0.000101
# Dunda                      0.000101
# Mwese                      0.000101
# Ngulu                      0.000101
# Vumilia                    0.000101
# Ngasamo                    0.000101
# Kambikatoto                0.000101
# Kimbe                      0.000101
# Milingoti Magharibi        0.000101
# Kyamuraile                 0.000101
# Kibasuka                   0.000101
# Usevya                     0.000101
# Malibwi                    0.000101
# Igandu                     0.000101
# Uyowa                      0.000101
# Myunga                     0.000101
# Magengati                  0.000101
# Mpamantwa                  0.000084
# Rau                        0.000084
# Nyakagomba                 0.000084
# Chikongola                 0.000084
# Litumbandyosi              0.000084
# Mwamishali                 0.000084
# Ichemba                    0.000084
# Bukiko                     0.000084
# Mkutano                    0.000084
# Kikomero                   0.000084
# Rubuga                     0.000084
# Mshangano                  0.000084
# Ushokola                   0.000084
# Mpinji                     0.000084
# Kisumwa                    0.000084
# Chuno                      0.000084
# Mhande                     0.000084
# Chali                      0.000084
# Oldonyo Sambu              0.000084
# Kabula                     0.000084
# Kamhanga                   0.000084
# Iyogwe                     0.000084
# Kiboriloni                 0.000084
# Makojo                     0.000084
# Bugwema                    0.000084
# Busanda                    0.000084
# Kaloleni                   0.000084
# Ihanamilo                  0.000084
# Nakatuguru                 0.000084
# Manzase                    0.000084
# Nditi                      0.000084
# Serengeti National Park    0.000084
# Bukwe                      0.000084
# Sirop                      0.000084
# Igigwa                     0.000084
# Talawanda                  0.000084
# Kitanga                    0.000084
# Mtanda                     0.000084
# Isanzu                     0.000084
# Gombero                    0.000084
# Itandula                   0.000084
# Mafyeko                    0.000084
# Minyughe                   0.000084
# Railway                    0.000084
# Gode Gode                  0.000084
# Nhundulu                   0.000084
# Milingoti Mashariki        0.000084
# Bubiki                     0.000084
# Itunduru                   0.000084
# Kanyenye                   0.000084
# Bwakila Juu                0.000084
# Katuma                     0.000084
# Marui                      0.000084
# Sombetini                  0.000067
# Mwanga Urban               0.000067
# Bukura                     0.000067
# Ng'haya                    0.000067
# Pangani Magharibi          0.000067
# Mbwara                     0.000067
# Kansay                     0.000067
# Ishunju                    0.000067
# Kinyala                    0.000067
# Nyugwa                     0.000067
# Itilo                      0.000067
# Kasimbu                    0.000067
# Shangani                   0.000067
# Maguu                      0.000067
# Uyui                       0.000067
# Vugiri                     0.000067
# Mtonya                     0.000067
# Kilimilire                 0.000067
# Machimboni                 0.000067
# Nangaru                    0.000067
# Langali                    0.000067
# Katandala                  0.000067
# Nyamunga                   0.000067
# Ilindi                     0.000067
# Mwangoi                    0.000067
# Olorien                    0.000067
# Matui                      0.000067
# Mhezi                      0.000067
# Sokon I                    0.000067
# Roche                      0.000067
# Manwanga                   0.000067
# Mvumi Mission              0.000067
# Bassodesh                  0.000067
# Kitura                     0.000067
# Oldeani                    0.000067
# Lemara                     0.000067
# Naiyobi                    0.000067
# Ipuli                      0.000051
# Santilya                   0.000051
# Lizaboni                   0.000051
# Nghambaku                  0.000051
# Mganza                     0.000051
# Daraja Mbili               0.000051
# Rusimbi                    0.000051
# Pangale                    0.000051
# Ng'ambo                    0.000051
# Chamazi                    0.000051
# Saunyi                     0.000051
# Magoroto                   0.000051
# Masasi                     0.000051
# Mpigamiti                  0.000051
# Goribe                     0.000051
# Namapwia                   0.000051
# Kawajense                  0.000051
# Tambuka Reli               0.000051
# Subira                     0.000051
# Kitangili                  0.000051
# Mbweni                     0.000051
# Mwashiku                   0.000051
# Kingerikiti                0.000051
# Ngarenaro                  0.000051
# Mazimbu                    0.000051
# Nangano                    0.000051
# Matwiga                    0.000051
# Mwembesongo                0.000051
# Isevya                     0.000051
# Shitage                    0.000051
# Masukulu                   0.000051
# Nangowe                    0.000051
# Sigili                     0.000051
# Ilujamate                  0.000051
# Changaa                    0.000051
# Mizibaziba                 0.000051
# Mcholi II                  0.000051
# Gongoni                    0.000051
# Sekei                      0.000051
# Rusaba                     0.000051
# Lubiri                     0.000051
# Kainam                     0.000051
# Jibondo                    0.000051
# Kakesio                    0.000051
# Kiusa                      0.000034
# Boma                       0.000034
# Nguvu Moja                 0.000034
# Heka Azimio                0.000034
# Kiyowela                   0.000034
# Fufu                       0.000034
# Bombambili                 0.000034
# Bukumi                     0.000034
# Shilalo                    0.000034
# Mwisi                      0.000034
# Itewe                      0.000034
# Mkwiti                     0.000034
# Kining'inila               0.000034
# Gitting                    0.000034
# Lutindi                    0.000034
# Isuto                      0.000034
# Laghanga                   0.000034
# Ijanija                    0.000034
# Baraa                      0.000034
# Kwasunga                   0.000034
# Membe                      0.000034
# Bukoko                     0.000034
# Kasiriri                   0.000034
# Chifunfu                   0.000034
# Gidahababieg               0.000034
# Kemambo                    0.000034
# Tunduma                    0.000034
# Kitembe                    0.000034
# Idodyandole                0.000034
# Bukondo                    0.000034
# Bondeni                    0.000034
# Ugala                      0.000034
# Vikumbulu                  0.000034
# Shabaka                    0.000034
# Salama                     0.000034
# Maskati                    0.000034
# Bureza                     0.000034
# Kimandolu                  0.000034
# Kimwani                    0.000034
# Misunkumilo                0.000034
# Magindu                    0.000034
# Mfaranyaki                 0.000034
# Budushi                    0.000034
# Manyondwe                  0.000034
# Semembela                  0.000034
# Levolosi                   0.000034
# Mkwajuni                   0.000034
# Luwalaje                   0.000034
# Murray                     0.000034
# Shigamba                   0.000034
# Negero                     0.000034
# Mkindi                     0.000034
# Pangwi                     0.000034
# Ilula                      0.000034
# Kimambi                    0.000034
# Nyanungu                   0.000034
# Tambukareli                0.000034
# Kapalala                   0.000034
# Nkome                      0.000034
# Ikweha                     0.000017
# Mkumbi                     0.000017
# Kapilula                   0.000017
# Burungura                  0.000017
# Kinungu                    0.000017
# Machinjioni                0.000017
# Igogo                      0.000017
# Kihangimahuka              0.000017
# Rasbura                    0.000017
# Thawi                      0.000017
# Themi                      0.000017
# Mlimani                    0.000017
# Ifinga                     0.000017
# Uwanja wa Ndege            0.000017
# Kirongo                    0.000017
# Nyamtinga                  0.000017
# Nsemulwa                   0.000017
# Ukata                      0.000017
# Korongoni                  0.000017
# Izia                       0.000017
# Matarawe                   0.000017
# Chinugulu                  0.000017
# Simbay                     0.000017
# Kitete                     0.000017
# Mawenzi                    0.000017
# Mwanga Kaskazini           0.000017
# Linda                      0.000017
# Sungwisi                   0.000017
# Mitole                     0.000017
# Uchindile                  0.000017
# Name: ward, Length: 2092, dtype: float64

# %%
df_categorical['public_meeting'].value_counts(normalize=True)
# Out:
# True     0.914899
# False    0.085101
# Name: public_meeting, dtype: float64

# %%
df_categorical['recorded_by'].value_counts(normalize=True)
# Out:
# GeoData Consultants Ltd    1.0
# Name: recorded_by, dtype: float64

# %%
df_categorical['scheme_management_cleaned'].value_counts(normalize=True)
# Out:
# VWC      0.619411
# Other    0.380589
# Name: scheme_management_cleaned, dtype: float64

# %%
df_categorical['permit'].value_counts(normalize=True)
# Out:
# True     0.705522
# False    0.294478
# Name: permit, dtype: float64

# %%
df_categorical['extraction_type'].value_counts(normalize=True)
# Out:
# gravity                      0.450842
# nira/tanira                  0.137273
# other                        0.108249
# submersible                  0.080202
# swn 80                       0.061785
# mono                         0.048232
# india mark ii                0.040404
# afridev                      0.029798
# ksb                          0.023822
# other - rope pump            0.007593
# other - swn 81               0.003855
# windmill                     0.001970
# india mark iii               0.001650
# cemo                         0.001515
# other - play pump            0.001431
# walimi                       0.000808
# climax                       0.000539
# other - mkulima/shinyanga    0.000034
# Name: extraction_type, dtype: float64

# %%
extraction_type_cleaned = []

for row in df_categorical['extraction_type']:
    if row == 'gravity':
        extraction_type_cleaned.append('gravity')
    else:
        extraction_type_cleaned.append('other')
    
df_categorical['extraction_type_cleaned'] = extraction_type_cleaned

# %%
df_categorical['extraction_type'].value_counts(normalize=True)
# Out:
# other      0.549158
# gravity    0.450842
# Name: extraction_type, dtype: float64

# %%
df_categorical['extraction_type_group'].value_counts(normalize=True)
# Out:
# gravity            0.450842
# nira/tanira        0.137273
# other              0.108249
# submersible        0.104024
# swn 80             0.061785
# mono               0.048232
# india mark ii      0.040404
# afridev            0.029798
# rope pump          0.007593
# other handpump     0.006128
# other motorpump    0.002054
# wind-powered       0.001970
# india mark iii     0.001650
# Name: extraction_type_group, dtype: float64

# %%
df_categorical['extraction_type_class'].value_counts(normalize=True)
# Out:
# gravity         0.450842
# handpump        0.277037
# other           0.108249
# submersible     0.104024
# motorpump       0.050286
# rope pump       0.007593
# wind-powered    0.001970
# Name: extraction_type_class, dtype: float64

# %%
df_categorical['management'].value_counts(normalize=True)
# Out:
# vwc                 0.681936
# wug                 0.109680
# water board         0.049377
# wua                 0.042677
# private operator    0.033182
# parastatal          0.029764
# water authority     0.015219
# other               0.014209
# company             0.011532
# unknown             0.009444
# other - school      0.001667
# trust               0.001313
# Name: management, dtype: float64

# %%
management_cleaned = []

for row in df_categorical['management']:
    if row == 'vwc':
        management_cleaned.append('vwc')
    else:
        management_cleaned.append('other')
    
df_categorical['management_cleaned'] = management_cleaned

# %%
df_categorical['management_cleaned'].value_counts(normalize=True)
# Out:
# vwc      0.681936
# other    0.318064
# Name: management_cleaned, dtype: float64

# %%
df_categorical.head()
# Out:
#                      basin  subvillage   region        lga        ward  public_meeting              recorded_by  permit extraction_type extraction_type_group extraction_type_class management management_group         payment payment_type water_quality quality_group      quantity quantity_group                source           source_type source_class              waterpoint_type waterpoint_type_group     id          target funder_cleaned installer_cleaned scheme_management_cleaned extraction_type_cleaned management_cleaned
# 0               Lake Nyasa    Mnyusi B   Iringa     Ludewa    Mundindi            True  GeoData Consultants Ltd   False         gravity               gravity               gravity        vwc       user-group    pay annually     annually          soft          good        enough         enough                spring                spring  groundwater           communal standpipe    communal standpipe  69572      functional          Other             Other                       VWC                 gravity                vwc
# 1            Lake Victoria     Nyamara     Mara  Serengeti       Natta            True  GeoData Consultants Ltd    True         gravity               gravity               gravity        wug       user-group       never pay    never pay          soft          good  insufficient   insufficient  rainwater harvesting  rainwater harvesting      surface           communal standpipe    communal standpipe   8776      functional          Other             Other                     Other                 gravity              other
# 2                  Pangani     Majengo  Manyara  Simanjiro     Ngorika            True  GeoData Consultants Ltd    True         gravity               gravity               gravity        vwc       user-group  pay per bucket   per bucket          soft          good        enough         enough                   dam                   dam      surface  communal standpipe multiple    communal standpipe  34310      functional          Other             Other                       VWC                 gravity                vwc
# 3  Ruvuma / Southern Coast  Mahakamani   Mtwara   Nanyumbu    Nanyumbu            True  GeoData Consultants Ltd    True           other           submersible           submersible        vwc       user-group       never pay    never pay          soft          good           dry            dry           machine dbh              borehole  groundwater  communal standpipe multiple    communal standpipe  67743  non functional          Other             Other                       VWC                   other                vwc
# 4            Lake Victoria  Kyanyamisa   Kagera    Karagwe  Nyakasimbi            True  GeoData Consultants Ltd    True         gravity               gravity               gravity      other            other       never pay    never pay          soft          good      seasonal       seasonal  rainwater harvesting  rainwater harvesting      surface           communal standpipe    communal standpipe  19728      functional          Other             Other                     Other                 gravity              other

# %%
df_categorical['management_group'].value_counts(normalize=True)
# Out:
# user-group    0.883670
# commercial    0.061246
# parastatal    0.029764
# other         0.015875
# unknown       0.009444
# Name: management_group, dtype: float64

# %%
management_group_cleaned = []

for row in df_categorical['management_group']:
    if row == 'user-group':
        management_group_cleaned.append('user-group')
    else:
        management_group_cleaned.append('other')
        
df_categorical['management_group_cleaned'] = management_group_cleaned

# %%
df_categorical['management_group_cleaned'].value_counts(normalize=True)
# Out:
# user-group    0.88367
# other         0.11633
# Name: management_group_cleaned, dtype: float64

# %%
df_categorical['payment'].value_counts(normalize=True)
# Out:
# never pay                0.426734
# pay per bucket           0.151263
# pay monthly              0.139731
# unknown                  0.137323
# pay when scheme fails    0.065892
# pay annually             0.061313
# other                    0.017744
# Name: payment, dtype: float64

# %%
payment_cleaned = []

for row in df_categorical['payment']:
    if row == 'never pay':
        payment_cleaned.append('never pay')
    else:
        payment_cleaned.append('other')
        
df_categorical['payment_cleaned'] = payment_cleaned

# %%
df_categorical['payment_cleaned'].value_counts(normalize=True)
# Out:
# other        0.573266
# never pay    0.426734
# Name: payment_cleaned, dtype: float64

# %%
df_categorical['water_quality'].value_counts(normalize=True)
# Out:
# soft                  0.855522
# salty                 0.081751
# unknown               0.031582
# milky                 0.013535
# coloured              0.008249
# salty abandoned       0.005707
# fluoride              0.003367
# fluoride abandoned    0.000286
# Name: water_quality, dtype: float64

# %%
water_quality_cleaned = []

for row in df_categorical['water_quality']:
    if row == 'soft':
        water_quality_cleaned.append('soft')
    else:
        water_quality_cleaned.append('other')
        
df_categorical['water_quality_cleaned'] = water_quality_cleaned

# %%
df_categorical['quality_group'].value_counts(normalize=True)
# Out:
# good        0.855522
# salty       0.087458
# unknown     0.031582
# milky       0.013535
# colored     0.008249
# fluoride    0.003653
# Name: quality_group, dtype: float64

# %%
quality_group_cleaned = []

for row in df_categorical['quality_group']:
    if row == 'good':
        quality_group_cleaned.append('good')
    else:
        quality_group_cleaned.append('other')
        
df_categorical['quality_group_cleaned'] = quality_group_cleaned

# %%
df_categorical['quality_group_cleaned'].value_counts(normalize=True)
# Out:
# good     0.855522
# other    0.144478
# Name: quality_group_cleaned, dtype: float64

# %%
df_categorical['quantity'].value_counts(normalize=True)
# Out:
# enough          0.558687
# insufficient    0.254697
# dry             0.105152
# seasonal        0.068182
# unknown         0.013283
# Name: quantity, dtype: float64

# %%
quantity_cleaned = []

for row in df_categorical['quantity']:
    if row == 'enough':
        quantity_cleaned.append('enough')
    else:
        quantity_cleaned.append('other')
        
df_categorical['quantity_cleaned'] = quantity_cleaned

# %%
df_categorical['quantity_cleaned'].value_counts(normalize=True)
# Out:
# enough    0.558687
# other     0.441313
# Name: quantity_cleaned, dtype: float64

# %%
df_categorical['source'].value_counts(normalize=True)
# Out:
# spring                  0.286549
# shallow well            0.283232
# machine dbh             0.186448
# river                   0.161818
# rainwater harvesting    0.038636
# hand dtw                0.014714
# lake                    0.012879
# dam                     0.011044
# other                   0.003569
# unknown                 0.001111
# Name: source, dtype: float64

# %%
source_cleaned = []

for row in df_categorical['source']:
    if row == 'spring':
        source_cleaned.append('spring')
    elif row == 'shallow well':
        source_cleaned.append('shallow well')
    elif row == 'machine dbh':
        source_cleaned.append('machine dbh')
    else:
        source_cleaned.append('other')
        
df_categorical['source_cleaned'] = source_cleaned

# %%
df_categorical['source_cleaned'].value_counts(normalize=True)
# Out:
# spring          0.286549
# shallow well    0.283232
# other           0.243771
# machine dbh     0.186448
# Name: source_cleaned, dtype: float64

# %%
df_categorical['source_class'].value_counts(normalize=True)
# Out:
# groundwater    0.770943
# surface        0.224377
# unknown        0.004680
# Name: source_class, dtype: float64

# %%
source_class_cleaned = []

for row in df_categorical['source_class']:
    if row == 'groundwater':
        source_class_cleaned.append('groundwater')
    else:
        source_class_cleaned.append('surface')
        
df_categorical['source_class_cleaned'] = source_class_cleaned

# %%
df_categorical['source_class_cleaned'].value_counts(normalize=True)
# Out:
# groundwater    0.770943
# surface        0.229057
# Name: source_class_cleaned, dtype: float64

# %%
df_categorical['waterpoint_type'].value_counts(normalize=True)
# Out:
# communal standpipe             0.480168
# hand pump                      0.294411
# other                          0.107407
# communal standpipe multiple    0.102744
# improved spring                0.013199
# cattle trough                  0.001953
# dam                            0.000118
# Name: waterpoint_type, dtype: float64

# %%
waterpoint_type_cleaned = []

for row in df_categorical['waterpoint_type']:
    if ((row == 'communal standpipe') or (row == 'communal standpipe multiple')):
        waterpoint_type_cleaned.append('standpipe')
    elif row == 'hand pump':
        waterpoint_type_cleaned.append('handpump')
    else:
        waterpoint_type_cleaned.append('other')
        
df_categorical['waterpoint_type_cleaned'] = waterpoint_type_cleaned

# %%
df_categorical['waterpoint_type_cleaned'].value_counts(normalize=True)
# Out:
# standpipe    0.582912
# handpump     0.294411
# other        0.122677
# Name: waterpoint_type_cleaned, dtype: float64

# %%
df_categorical['waterpoint_type_group'].value_counts(normalize=True)
# Out:
# communal standpipe    0.582912
# hand pump             0.294411
# other                 0.107407
# improved spring       0.013199
# cattle trough         0.001953
# dam                   0.000118
# Name: waterpoint_type_group, dtype: float64
